# %% [markdown]
# # **CLUSTERING NOTEBOOK**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from umap.umap_ import UMAP
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
from sklearn.decomposition import PCA
import plotly.express as px
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

# Get the absolute path of the source_code folder
source_code_path = os.path.abspath('../source_code')

# Add the source_code folder to sys.path
if source_code_path not in sys.path:
    sys.path.append(source_code_path)

from utils import *
from preprocessing import *
from clustering import *
from analysis import *

# Get the absolute path of the source_code folder
clustering_outputs_path = os.path.abspath('../clustering_outputs')

# Add the source_code folder to sys.path
if clustering_outputs_path not in sys.path:
    sys.path.append(clustering_outputs_path)

# %% [markdown]
# ## Load Data

# %%
customer_info = load_dataset('../customer_info.csv')

# %%
#customer_info.columns

# %%
# Calling the clusters
hierarchical8_notscaled=load_dataset('../clustering_outputs/hierarchical8_notscaled.csv')
hierarchical8_scaled=load_dataset('../clustering_outputs/hierarchical8_scaled.csv')

# %%
customer_basket = load_dataset('../customer_basket.csv')

# %% [markdown]
# ## Analysis

# %%
vars, cluster_avg, database_avg=compute_average_multi(hierarchical8_scaled, 'cluster')

# %%
plot_all_clusters_profile_plotly(vars, cluster_avg, database_avg)

# %% [markdown]
# ## Association Rules

# %%
df_items2, items_list2 = transform_dataset(customer_basket, hierarchical8_notscaled,2)

# %%
df_items2, items_list2
# Out:
# (       airpods  almonds  antioxydant juice  asparagus  avocado  babies food  \
#  0        False    False              False      False    False         True
#  1        False    False              False      False    False        False
#  2        False    False              False      False    False        False
#  3        False    False              False      False    False        False
#  4        False    False              False      False    False        False
#  ...        ...      ...                ...        ...      ...          ...
#  17037    False    False              False      False    False        False
#  17038    False    False              False      False    False        False
#  17039    False    False              False      False    False        False
#  17040    False    False              False      False    False        False
#  17041    False    False              False       True    False        False
#
#         bacon  barbecue sauce   beer  black beer  ...  vacuum cleaner  \
#  0      False           False  False       False  ...           False
#  1      False           False  False       False  ...           False
#  2      False           False  False       False  ...           False
#  3      False           False  False       False  ...           False
#  4      False           False  False       False  ...           False
#  ...      ...             ...    ...         ...  ...             ...
#  17037  False           False  False       False  ...           False
#  17038  False           False  False       False  ...           False
#  17039  False           False  False       False  ...           False
#  17040  False           False  False       False  ...           False
#  17041  False           False  False       False  ...           False
#
#         vegetables mix  water spray  white wine  whole weat flour  \
#  0               False        False       False             False
#  1               False        False       False             False
#  2               False         True       False             False
#  3               False        False       False             False
#  4               False        False       False             False
#  ...               ...          ...         ...               ...
#  17037           False        False       False             False
#  17038           False         True       False             False
#  17039           False        False       False             False
#  17040           False        False       False             False
#  17041           False        False       False             False
#
#         whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
#  0                  False             False  False        False     False
#  1                  False             False  False        False     False
#  2                  False             False  False        False      True
#  3                  False             False  False        False     False
#  4                  False             False  False        False     False
#  ...                  ...               ...    ...          ...       ...
#  17037              False             False  False        False     False
#  17038              False              True   True        False     False
#  17039              False             False  False        False     False
#  17040              False             False  False        False     False
#  17041              False             False  False        False     False
#
#  [17042 rows x 164 columns],
#  [['soup',
#    'shallot',
#    'cake',
#    'fresh bread',
#    'cream',
#    'carrots',
#    'babies food',
#    'ham',
#    'cookies',
#    'salad',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'soup', 'napkins', 'rice', 'oil', 'tea'],
#   ['zucchini',
#    'grated cheese',
#    'ketchup',
#    'oil',
#    'pokemon scarlet',
#    'milk',
#    'water spray',
#    'chicken',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'frozen smoothie',
#    'oil',
#    'ham',
#    'phone car charger',
#    'cologne',
#    'iMac',
#    'tea'],
#   ['cake', 'cream', 'corn', 'blueberries', 'burgers'],
#   ['oil', 'babies food', 'cooking oil'],
#   ['soup', 'protein bar', 'oil', 'toothpaste', 'ham', 'cooking oil', 'tea'],
#   ['candy bars',
#    'cake',
#    'whole wheat rice',
#    'oil',
#    'portal',
#    'black tea',
#    'fresh bread',
#    'ham',
#    'green beans',
#    'cooking oil'],
#   ['meatballs',
#    'cottage cheese',
#    'french fries',
#    'turkey',
#    'oil',
#    'chocolate bread',
#    'tomatoes',
#    'cologne',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cooking oil',
#    'cereals',
#    'oil',
#    'dog food',
#    'deodorant',
#    'tomatoes',
#    'yogurt cake',
#    'pet food',
#    'salmon',
#    'olive oil',
#    'fresh tuna',
#    'tea'],
#   ['oil', 'pasta', 'blueberries', 'olive oil', 'mint', 'tomato juice', 'tea'],
#   ['whole wheat rice',
#    'meatballs',
#    'frozen smoothie',
#    'oil',
#    'ketchup',
#    'gums',
#    'toothpaste',
#    'cooking oil',
#    'green grapes',
#    'tea'],
#   ['cake',
#    'napkins',
#    'phone charger',
#    'french fries',
#    'oil',
#    'ketchup',
#    'shower gel',
#    'gums',
#    'whole weat flour',
#    'muffins',
#    'pepper',
#    'burgers',
#    'bluetooth headphones',
#    'cooking oil'],
#   ['soup',
#    'napkins',
#    'oatmeal',
#    'french fries',
#    'gadget for tiktok streaming',
#    'gums',
#    'cooking oil',
#    'mushroom cream sauce',
#    'tea'],
#   ['soup',
#    'megaman zero 3',
#    'french fries',
#    'turkey',
#    'oil',
#    'ketchup',
#    'gums',
#    'milk',
#    'babies food',
#    'toilet paper',
#    'salt',
#    'tea'],
#   ['cream', 'cereals', 'rice', 'napkins'],
#   ['soup', 'oatmeal', 'oil', 'green beans', 'metroid fusion', 'tea'],
#   ['candy bars',
#    'cake',
#    'strong cheese',
#    'cereals',
#    'oil',
#    'final fantasy XXII',
#    'fresh bread',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'megaman zero 3',
#    'grated cheese',
#    'oil',
#    'fresh bread',
#    'pokemon scarlet',
#    'babies food',
#    'salmon',
#    'toilet paper',
#    'cooking oil'],
#   ['ketchup', 'yogurt cake', 'cooking oil', 'oil'],
#   ['shampoo',
#    'soup',
#    'shallot',
#    'napkins',
#    'oil',
#    'gadget for tiktok streaming',
#    'toothpaste',
#    'half-life 2',
#    'cooking oil'],
#   ['oatmeal', 'frozen vegetables', 'oil', 'sandwich', 'cooking oil'],
#   ['candy bars',
#    'napkins',
#    'rice',
#    'pokemon shield',
#    'oil',
#    'ketchup',
#    'asparagus',
#    'shower gel',
#    'milk',
#    'parmesan cheese',
#    'escalope',
#    'cooking oil',
#    'tea'],
#   ['burgers',
#    'napkins',
#    'turkey',
#    'pokemon shield',
#    'oil',
#    'dog food',
#    'shower gel',
#    'muffins',
#    'corn',
#    'ground beef',
#    'cologne',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'spaghetti',
#    'mashed potato',
#    'strong cheese',
#    'frozen vegetables',
#    'oil',
#    'avocado',
#    'gums',
#    'babies food',
#    'tomato sauce'],
#   ['candy bars',
#    'pickles',
#    'final fantasy XIX',
#    'chocolate',
#    'soda',
#    'cottage cheese',
#    'cereals',
#    'oil',
#    'honey',
#    'gums',
#    'cream',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['whole wheat pasta',
#    'napkins',
#    'oil',
#    'megaman zero 2',
#    'minecraft',
#    'toilet paper',
#    'cooking oil',
#    'tea'],
#   ['protein bar',
#    'whole wheat rice',
#    'oatmeal',
#    'hot dogs',
#    'oil',
#    'shower gel',
#    'milk',
#    'burgers',
#    'tomato sauce',
#    'cooking oil',
#    'green grapes'],
#   ['soup',
#    'cake',
#    'oatmeal',
#    'grated cheese',
#    'oil',
#    'cream',
#    'muffins',
#    'pet food',
#    'eggs',
#    'tea'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'cottage cheese',
#    'grated cheese',
#    'strong cheese',
#    'oil',
#    'portal',
#    'fresh bread',
#    'whole weat flour',
#    'parmesan cheese',
#    'eggs'],
#   ['cereals', 'whole wheat rice', 'iPad', 'tea'],
#   ['burgers',
#    'candy bars',
#    'cake',
#    'soup',
#    'mashed potato',
#    'ring light',
#    'olive oil',
#    'ketchup',
#    'gluten free bar',
#    'pet food',
#    'babies food',
#    'chili',
#    'cologne',
#    'toilet paper',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'energy bar',
#    'flax seed',
#    'sparkling water',
#    'honey',
#    'gums',
#    'muffins',
#    'babies food',
#    'melons',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'cooking oil',
#    'oil',
#    'fresh bread',
#    'gums',
#    'pasta',
#    'muffins',
#    'chicken',
#    'body spray'],
#   ['tooth brush',
#    'cotton buds',
#    'turkey',
#    'oil',
#    'mayonnaise',
#    'extra dark chocolate',
#    'toilet paper',
#    'cooking oil'],
#   ['soup',
#    'mashed potato',
#    'strong cheese',
#    'oil',
#    'deodorant',
#    'half-life 2',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'cottage cheese',
#    'french fries',
#    'ring light',
#    'vegetables mix',
#    'shrimp',
#    'milk',
#    'spinach'],
#   ['candy bars',
#    'napkins',
#    'turkey',
#    'oil',
#    'strawberries',
#    'ketchup',
#    'burger sauce',
#    'final fantasy XXII',
#    'fresh bread',
#    'pet food',
#    'escalope',
#    'ratchet & clank 3',
#    'tea'],
#   ['meatballs', 'beer', 'oil', 'olive oil', 'zucchini'],
#   ['soup',
#    'tooth brush',
#    'napkins',
#    'french fries',
#    'turkey',
#    'oil',
#    'pokemon shield',
#    'strawberries',
#    'asparagus',
#    'mayonnaise',
#    'gums',
#    'pasta',
#    'escalope',
#    'eggs',
#    'burgers',
#    'mint',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'rice',
#    'strong cheese',
#    'pokemon violet',
#    'oil',
#    'milk',
#    'escalope',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'whole wheat rice',
#    'oil',
#    'flax seed',
#    'ratchet & clank',
#    'milk',
#    'cream',
#    'gums',
#    'pet food',
#    'mayonnaise',
#    'yogurt cake',
#    'tea'],
#   ['candy bars', 'cake', 'oatmeal', 'hot dogs', 'french fries', 'butter'],
#   ['cake',
#    'phone charger',
#    'strong cheese',
#    'oil',
#    'asparagus',
#    'gums',
#    'muffins',
#    'ham',
#    'green grapes'],
#   ['cake', 'french fries', 'oil', 'muffins', 'sandwich', 'cooking oil', 'tea'],
#   ['whole weat flour', 'muffins', 'corn', 'butter'],
#   ['tooth brush',
#    'shallot',
#    'mashed potato',
#    'cottage cheese',
#    'french fries',
#    'strong cheese',
#    'oil',
#    'gums',
#    'yogurt cake',
#    'megaman zero'],
#   ['cake',
#    'cologne',
#    'grated cheese',
#    'gums',
#    'metroid prime',
#    'sandwich',
#    'light mayo',
#    'cooking oil',
#    'tea'],
#   ['pickles',
#    'cottage cheese',
#    'french fries',
#    'oil',
#    'ketchup',
#    'gums',
#    'sandwich',
#    'burgers',
#    'tea'],
#   ['yams',
#    'strong cheese',
#    'cereals',
#    'oil',
#    'tomatoes',
#    'cologne',
#    'body spray',
#    'butter',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['cottage cheese',
#    'oil',
#    'catfish',
#    'megaman zero 4',
#    'barbecue sauce',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'oatmeal',
#    'megaman zero 3',
#    'oil',
#    'parmesan cheese',
#    'muffins',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['pickles',
#    'soup',
#    'cake',
#    'french fries',
#    'oil',
#    'deodorant',
#    'shower gel',
#    'muffins',
#    'sandwich',
#    'cat food',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['yams',
#    'cake',
#    'napkins',
#    'rice',
#    'french fries',
#    'fromage blanc',
#    'gums',
#    'mayonnaise',
#    'pet food',
#    'salad',
#    'cooking oil'],
#   ['cake',
#    'spaghetti',
#    'rice',
#    'muffins',
#    'babies food',
#    'yogurt cake',
#    'body spray',
#    'tomato sauce',
#    'cooking oil'],
#   ['soup',
#    'meatballs',
#    'spaghetti',
#    'rice',
#    'oatmeal',
#    'oil',
#    'toothpaste',
#    'milk',
#    'muffins',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'eggplant',
#    'french fries',
#    'cereals',
#    'oil',
#    'frozen smoothie',
#    'asparagus',
#    'pokemon scarlet',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'whole wheat pasta',
#    'oil',
#    'fresh bread',
#    'whole weat flour',
#    'carrots',
#    'light mayo',
#    'tomato juice',
#    'tomato sauce'],
#   ['ketchup', 'oil', 'pasta', 'muffins', 'green beans', 'tea'],
#   ['napkins',
#    'eggplant',
#    'oil',
#    'fresh bread',
#    'parmesan cheese',
#    'muffins',
#    'salmon',
#    'tea'],
#   ['cake',
#    'french fries',
#    'fresh bread',
#    'sandwich',
#    'toilet paper',
#    'butter',
#    'tea'],
#   ['bramble',
#    'soup',
#    'cake',
#    'napkins',
#    'oil',
#    'gadget for tiktok streaming',
#    'fresh bread',
#    'tomatoes',
#    'canned_tuna',
#    'blueberries',
#    'mint',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'spaghetti',
#    'french fries',
#    'oil',
#    'fresh bread',
#    'gums',
#    'pet food',
#    'half-life: alyx',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'meatballs',
#    'ring light',
#    'oil',
#    'pancakes',
#    'nonfat milk',
#    'chili',
#    'cookies',
#    'protein bar'],
#   ['candy bars', 'napkins', 'sparkling water', 'muffins', 'cooking oil'],
#   ['burgers',
#    'cake',
#    'cereals',
#    'oil',
#    'cookies',
#    'body spray',
#    'salad',
#    'barbecue sauce',
#    'cooking oil'],
#   ['candy bars',
#    'cake',
#    'french fries',
#    'mineral water',
#    'oil',
#    'asparagus',
#    'low fat yogurt',
#    'fresh bread',
#    'shrimp',
#    'gums',
#    'cream',
#    'pet food',
#    'portal 2',
#    'cooking oil',
#    'metroid fusion'],
#   ['cake', 'whole wheat rice', 'muffins', 'cooking oil', 'tea'],
#   ['soup',
#    'cake',
#    'oatmeal',
#    'grated cheese',
#    'french fries',
#    'half-life 2',
#    'eggs',
#    'tea'],
#   ['soup',
#    'cake',
#    'oatmeal',
#    'oil',
#    'deodorant',
#    'low fat yogurt',
#    'muffins',
#    'pet food',
#    'almonds',
#    'cologne',
#    'megaman zero',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'oil',
#    'airpods',
#    'black tea',
#    'final fantasy XXII',
#    'babies food',
#    'white wine',
#    'burgers',
#    'salt',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['yams', 'oil', 'pasta', 'cooking oil', 'green grapes'],
#   ['cotton buds',
#    'napkins',
#    'zucchini',
#    'strong cheese',
#    'oil',
#    'strawberries',
#    'parmesan cheese',
#    'muffins',
#    'whole weat flour',
#    'phone car charger',
#    'olive oil',
#    'salad',
#    'body spray',
#    'vacuum cleaner',
#    'tea'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'strong cheese',
#    'mineral water',
#    'oil',
#    'pokemon sword',
#    'mayonnaise',
#    'tea'],
#   ['frozen smoothie',
#    'oil',
#    'fromage blanc',
#    'burger sauce',
#    'vegetables mix',
#    'fresh bread',
#    'cookies',
#    'butter'],
#   ['candy bars',
#    'soup',
#    'napkins',
#    'french fries',
#    'oil',
#    'shower gel',
#    'gums',
#    'melons',
#    'yogurt cake',
#    'blueberries',
#    'eggs',
#    'olive oil'],
#   ['cider',
#    'soup',
#    'dessert wine',
#    'cake',
#    'soda',
#    'shampoo',
#    'oil',
#    'flax seed',
#    'toothpaste',
#    'whole weat flour',
#    'cream',
#    'final fantasy XX',
#    'chicken',
#    'metroid fusion',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'rice',
#    'ratchet & clank',
#    'gums',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'meatballs',
#    'turkey',
#    'oil',
#    'bacon',
#    'pokemon scarlet',
#    'gums',
#    'cookies',
#    'tomato juice',
#    'barbecue sauce',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'spaghetti',
#    'strong cheese',
#    'oil',
#    'green beans',
#    'asparagus',
#    'gums',
#    'whole weat flour',
#    'muffins',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['yams',
#    'shower gel',
#    'vegetables mix',
#    'salmon',
#    'mushroom cream sauce',
#    'tea'],
#   ['tooth brush', 'whole wheat rice', 'oil', 'fresh bread', 'gums', 'tea'],
#   ['soup', 'cake', 'soda', 'oil', 'airpods', 'half-life 2', 'portal 2'],
#   ['soup', 'oil', 'cereals', 'tea'],
#   ['candy bars',
#    'cake',
#    'airpods',
#    'ketchup',
#    'oil',
#    'light mayo',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'shower gel', 'tea'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'zucchini',
#    'rice',
#    'french fries',
#    'strong cheese',
#    'ketchup',
#    'laptop',
#    'fresh bread',
#    'toothpaste',
#    'pet food',
#    'cookies',
#    'megaman zero 4',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'shallot',
#    'spaghetti',
#    'frozen smoothie',
#    'oil',
#    'strawberries',
#    'ketchup',
#    'final fantasy XXII',
#    'shrimp',
#    'cologne',
#    'cooking oil'],
#   ['candy bars',
#    'bramble',
#    'mineral water',
#    'shower gel',
#    'toothpaste',
#    'cream',
#    'extra dark chocolate',
#    'eggs',
#    'cooking oil'],
#   ['soda',
#    'chutney',
#    'oatmeal',
#    'strong cheese',
#    'french fries',
#    'oil',
#    'strawberries',
#    'shower gel',
#    'final fantasy XXII',
#    'gums',
#    'whole weat flour',
#    'almonds',
#    'blueberries',
#    'spinach',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'bacon', 'oil', 'gums', 'yogurt cake', 'cooking oil'],
#   ['candy bars', 'grated cheese', 'fromage blanc', 'gums', 'green tea'],
#   ['energy bar',
#    'mineral water',
#    'seabass',
#    'oil',
#    'melons',
#    'cookies',
#    'metroid fusion'],
#   ['soda', 'oil', 'fresh bread', 'gums', 'cologne', 'cooking oil'],
#   ['fresh bread', 'gums', 'pokemon scarlet', 'tea'],
#   ['oil',
#    'ketchup',
#    'airpods',
#    'sparkling water',
#    'gums',
#    'cream',
#    'yogurt cake',
#    'body spray',
#    'cooking oil'],
#   ['candy bars',
#    'cologne',
#    'laptop',
#    'oil',
#    'low fat yogurt',
#    'fresh bread',
#    'gums',
#    'mayonnaise',
#    'white wine',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'napkins',
#    'strong cheese',
#    'french fries',
#    'oil',
#    'avocado',
#    'gums',
#    'tomatoes',
#    'mayonnaise',
#    'metroid fusion',
#    'cookies',
#    'cooking oil',
#    'mushroom cream sauce',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'cologne',
#    'gums',
#    'muffins',
#    'yogurt cake',
#    'ratchet & clank 3',
#    'burgers',
#    'megaman zero 4',
#    'cooking oil'],
#   ['french fries',
#    'oil',
#    'fresh bread',
#    'muffins',
#    'yogurt cake',
#    'white wine',
#    'cologne',
#    'megaman zero 4',
#    'butter',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'oil',
#    'ratchet & clank',
#    'gums',
#    'escalope',
#    'half-life: alyx',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['cereals',
#    'ketchup',
#    'low fat yogurt',
#    'parmesan cheese',
#    'pet food',
#    'sandwich',
#    'cookies',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'tooth brush',
#    'oatmeal',
#    'turkey',
#    'fresh bread',
#    'toothpaste',
#    'milk',
#    'muffins',
#    'sandwich',
#    'toilet paper',
#    'salad',
#    'cooking oil'],
#   ['soup',
#    'oatmeal',
#    'oil',
#    'pasta',
#    'cookies',
#    'megaman zero 4',
#    'red wine',
#    'cooking oil',
#    'tea'],
#   ['chocolate', 'cream', 'trout', 'iMac', 'zucchini'],
#   ['cake', 'oil', 'portal', 'yogurt cake', 'pet food'],
#   ['soup',
#    'cake',
#    'napkins',
#    'spaghetti',
#    'strong cheese',
#    'french fries',
#    'gadget for tiktok streaming',
#    'cereals',
#    'final fantasy XXII',
#    'extra dark chocolate',
#    'olive oil',
#    'mint',
#    'tea'],
#   ['fresh bread', 'napkins', 'tomato sauce', 'tea'],
#   ['candy bars',
#    'soda',
#    'bramble',
#    'cottage cheese',
#    'turkey',
#    'oil',
#    'gadget for tiktok streaming',
#    'milk',
#    'muffins',
#    'pet food',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'cake', 'laptop', 'frozen smoothie', 'fresh bread', 'milk'],
#   ['candy bars',
#    'oil',
#    'gluten free bar',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['soup',
#    'napkins',
#    'oil',
#    'muffins',
#    'pasta',
#    'olive oil',
#    'barbecue sauce'],
#   ['oatmeal',
#    'oil',
#    'shower gel',
#    'pokemon scarlet',
#    'milk',
#    'hand protein bar',
#    'escalope',
#    'barbecue sauce',
#    'chocolate bread'],
#   ['candy bars',
#    'cake',
#    'oil',
#    'shower gel',
#    'cream',
#    'pasta',
#    'green beans',
#    'iMac',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'oil',
#    'fromage blanc',
#    'fresh bread',
#    'minecraft',
#    'babies food',
#    'cooking oil'],
#   ['final fantasy XIX',
#    'soda',
#    'cake',
#    'mashed potato',
#    'oil',
#    'bacon',
#    'flax seed',
#    'cream',
#    'babies food',
#    'pet food',
#    'chili',
#    'olive oil',
#    'tea'],
#   ['cake',
#    'spaghetti',
#    'mashed potato',
#    'oil',
#    'milk',
#    'burgers',
#    'toilet paper',
#    'cat food'],
#   ['soup',
#    'oatmeal',
#    'iPad',
#    'cottage cheese',
#    'oil',
#    'toothpaste',
#    'cream',
#    'gums',
#    'olive oil',
#    'red wine',
#    'tea'],
#   ['final fantasy XIX', 'cotton buds', 'napkins', 'chutney', 'tea'],
#   ['shampoo',
#    'final fantasy XIX',
#    'yams',
#    'oatmeal',
#    'french fries',
#    'oil',
#    'flax seed',
#    'mayonnaise',
#    'red wine',
#    'herb & pepper'],
#   ['energy bar',
#    'oil',
#    'airpods',
#    'strawberries',
#    'gums',
#    'energy drink',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['final fantasy XIX',
#    'shallot',
#    'mashed potato',
#    'frozen vegetables',
#    'oil',
#    'water spray',
#    'iMac'],
#   ['oatmeal',
#    'rice',
#    'ring light',
#    'cereals',
#    'oil',
#    'asparagus',
#    'shower gel',
#    'ratchet & clank',
#    'metroid prime',
#    'final fantasy XX',
#    'body spray',
#    'cooking oil',
#    'tea'],
#   ['cider',
#    'soup',
#    'barbecue sauce',
#    'ketchup',
#    'avocado',
#    'shower gel',
#    'gums',
#    'salad',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'whole wheat rice',
#    'napkins',
#    'grated cheese',
#    'oil',
#    'fromage blanc',
#    'white wine',
#    'eggs',
#    'cooking oil'],
#   ['oil',
#    'fromage blanc',
#    'fresh bread',
#    'toothpaste',
#    'pancakes',
#    'pasta',
#    'final fantasy XX',
#    'half-life: alyx',
#    'tea'],
#   ['dessert wine',
#    'cake',
#    'napkins',
#    'oil',
#    'extra dark chocolate',
#    'cooking oil',
#    'tea'],
#   ['oil',
#    'ketchup',
#    'gums',
#    'parmesan cheese',
#    'hand protein bar',
#    'olive oil',
#    'tomato sauce'],
#   ['soup', 'cake', 'napkins', 'oil', 'sparkling water', 'olive oil', 'tea'],
#   ['yams',
#    'black beer',
#    'cake',
#    'french fries',
#    'dog food',
#    'milk',
#    'muffins',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cottage cheese',
#    'mineral water',
#    'oil',
#    'frozen vegetables',
#    'final fantasy XXII',
#    'ratchet & clank',
#    'gums',
#    'tomatoes',
#    'yogurt cake',
#    'cooking oil',
#    'tea'],
#   ['napkins',
#    'oil',
#    'fromage blanc',
#    'asparagus',
#    'vegetables mix',
#    'gums',
#    'muffins',
#    'pasta',
#    'half-life 2',
#    'cooking oil',
#    'tea'],
#   ['light cream',
#    'napkins',
#    'french fries',
#    'muffins',
#    'cookies',
#    'body spray',
#    'cooking oil'],
#   ['yams', 'oil', 'white wine', 'water spray', 'green grapes'],
#   ['cake',
#    'napkins',
#    'cotton buds',
#    'french fries',
#    'frozen vegetables',
#    'oil',
#    'catfish',
#    'fresh bread',
#    'ratchet & clank',
#    'pet food',
#    'yogurt cake',
#    'phone car charger',
#    'cooking oil',
#    'tea'],
#   ['gluten free bar',
#    'shower gel',
#    'ratchet & clank',
#    'parmesan cheese',
#    'babies food',
#    'white wine',
#    'cooking oil',
#    'tea'],
#   ['iphone 10',
#    'hot dogs',
#    'pokemon shield',
#    'toothpaste',
#    'carrots',
#    'muffins',
#    'tomatoes',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['black beer',
#    'tooth brush',
#    'whole wheat pasta',
#    'whole wheat rice',
#    'samsung galaxy 10',
#    'strong cheese',
#    'oil',
#    'flax seed',
#    'burger sauce',
#    'fresh bread',
#    'gums',
#    'herb & pepper',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'whole wheat pasta',
#    'oatmeal',
#    'barbecue sauce',
#    'asparagus',
#    'herb & pepper',
#    'cooking oil',
#    'cauliflower'],
#   ['cake', 'cottage cheese', 'oil', 'cream', 'mint green tea', 'tea'],
#   ['oil', 'flax seed', 'fresh bread', 'cream', 'cooking oil'],
#   ['shampoo',
#    'bramble',
#    'napkins',
#    'mint green tea',
#    'strong cheese',
#    'oil',
#    'bacon',
#    'deodorant',
#    'fresh bread',
#    'gums',
#    'muffins',
#    'olive oil',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'napkins',
#    'spaghetti',
#    'oil',
#    'milk',
#    'muffins',
#    'almonds',
#    'olive oil',
#    'tea'],
#   ['candy bars',
#    'dessert wine',
#    'rice',
#    'french fries',
#    'minecraft',
#    'olive oil',
#    'tea'],
#   ['soda', 'grated cheese', 'oil', 'mayonnaise', 'yogurt cake'],
#   ['cake',
#    'megaman zero 3',
#    'dog food',
#    'sparkling water',
#    'final fantasy XXII',
#    'fresh tuna',
#    'chocolate bread'],
#   ['soup',
#    'spaghetti',
#    'phone charger',
#    'french fries',
#    'oil',
#    'seabass',
#    'babies food',
#    'corn',
#    'half-life: alyx',
#    'green beans',
#    'cooking oil',
#    'tea'],
#   ['bramble',
#    'oil',
#    'tomatoes',
#    'muffins',
#    'babies food',
#    'parmesan cheese',
#    'tea'],
#   ['pickles', 'oil', 'ham', 'cooking oil'],
#   ['oatmeal',
#    'cotton buds',
#    'oil',
#    'ketchup',
#    'ratchet & clank',
#    'gums',
#    'tomatoes',
#    'babies food',
#    'ratchet & clank 3',
#    'body spray',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'oatmeal',
#    'light cream',
#    'oil',
#    'airpods',
#    'fresh bread',
#    'gums',
#    'pasta',
#    'babies food',
#    'melons',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'meatballs',
#    'antioxydant juice',
#    'spaghetti',
#    'french fries',
#    'oil',
#    'flax seed',
#    'gums',
#    'pet food',
#    'yogurt cake',
#    'escalope',
#    'olive oil',
#    'salad',
#    'french wine'],
#   ['soup', 'rice', 'oil', 'asparagus', 'herb & pepper', 'cooking oil'],
#   ['cake', 'oil', 'asparagus', 'pasta', 'butter'],
#   ['dessert wine', 'oil', 'deodorant', 'pet food', 'cooking oil'],
#   ['final fantasy XIX',
#    'light cream',
#    'ketchup',
#    'pokemon scarlet',
#    'cooking oil'],
#   ['soup',
#    'tooth brush',
#    'cottage cheese',
#    'oil',
#    'fromage blanc',
#    'airpods',
#    'melons',
#    'pet food',
#    'pepper',
#    'tomato sauce'],
#   ['candy bars', 'ring light', 'oil', 'muffins', 'green beans', 'tea'],
#   ['candy bars',
#    'cider',
#    'iPad',
#    'oil',
#    'mayonnaise',
#    'trout',
#    'yogurt cake',
#    'spinach',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'yams',
#    'cake',
#    'spaghetti',
#    'oil',
#    'bacon',
#    'gadget for tiktok streaming',
#    'low fat yogurt',
#    'fresh bread',
#    'muffins',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['yams',
#    'cake',
#    'gums',
#    'body spray',
#    'bluetooth headphones',
#    'cooking oil'],
#   ['soup',
#    'cake',
#    'napkins',
#    'oil',
#    'final fantasy XXII',
#    'muffins',
#    'ratchet & clank 2',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'hot dogs',
#    'french fries',
#    'oil',
#    'ketchup',
#    'seabass',
#    'fresh bread',
#    'metroid prime',
#    'eggs',
#    'toilet paper',
#    'bluetooth headphones'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'oil',
#    'black tea',
#    'gums',
#    'parmesan cheese',
#    'cooking oil'],
#   ['tooth brush',
#    'cake',
#    'napkins',
#    'oil',
#    'fresh bread',
#    'yogurt cake',
#    'extra dark chocolate',
#    'half-life 2',
#    'burgers',
#    'salt',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cereals',
#    'oil',
#    'airpods',
#    'whole weat flour',
#    'energy drink',
#    'ham',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['soup',
#    'dessert wine',
#    'french fries',
#    'cereals',
#    'oil',
#    'deodorant',
#    'sparkling water',
#    'cream',
#    'gums',
#    'nonfat milk',
#    'babies food',
#    'body spray',
#    'cat food'],
#   ['candy bars',
#    'oatmeal',
#    'spaghetti',
#    'mashed potato',
#    'oil',
#    'fresh bread',
#    'milk',
#    'gums',
#    'whole weat flour',
#    'final fantasy XX',
#    'mint',
#    'cooking oil'],
#   ['cake',
#    'whole wheat pasta',
#    'oil',
#    'muffins',
#    'metroid prime',
#    'toilet paper',
#    'tea'],
#   ['yams', 'french fries', 'oil', 'honey', 'toothpaste', 'cooking oil', 'tea'],
#   ['black beer',
#    'soup',
#    'cake',
#    'napkins',
#    'spaghetti',
#    'phone charger',
#    'ring light',
#    'ketchup',
#    'oil',
#    'gums',
#    'almonds',
#    'ham',
#    'cologne',
#    'cooking oil'],
#   ['cake',
#    'mint green tea',
#    'mineral water',
#    'oil',
#    'body spray',
#    'tomato sauce',
#    'toilet paper',
#    'tea'],
#   ['cake',
#    'oil',
#    'milk',
#    'brownies',
#    'burgers',
#    'iMac',
#    'tomato sauce',
#    'tea'],
#   ['candy bars', 'cottage cheese', 'french fries', 'oil', 'muffins', 'tea'],
#   ['cake',
#    'napkins',
#    'oil',
#    'fresh bread',
#    'mayonnaise',
#    'babies food',
#    'yogurt cake',
#    'cooking oil'],
#   ['candy bars',
#    'napkins',
#    'phone charger',
#    'oil',
#    'asparagus',
#    'vegetables mix',
#    'gums',
#    'muffins',
#    'salad',
#    'tomato sauce',
#    'cooking oil',
#    'metroid fusion'],
#   ['candy bars',
#    'flax seed',
#    'muffins',
#    'babies food',
#    'half-life: alyx',
#    'sandwich',
#    'body spray',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'spaghetti',
#    'energy bar',
#    'strong cheese',
#    'french fries',
#    'oil',
#    'fromage blanc',
#    'final fantasy XXII',
#    'gums',
#    'whole weat flour',
#    'ratchet & clank 2',
#    'yogurt cake',
#    'milk',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['oil',
#    'fresh bread',
#    'gums',
#    'toothpaste',
#    'cream',
#    'green tea',
#    'metroid prime',
#    'salmon',
#    'mint',
#    'herb & pepper',
#    'protein bar'],
#   ['candy bars',
#    'cake',
#    'cooking oil',
#    'oil',
#    'sparkling water',
#    'cream',
#    'muffins',
#    'babies food',
#    'zucchini',
#    'tea'],
#   ['cake',
#    'napkins',
#    'light cream',
#    'megaman zero 3',
#    'oil',
#    'asparagus',
#    'almonds',
#    'yogurt cake',
#    'muffins',
#    'salad',
#    'cooking oil',
#    'tea'],
#   ['cake', 'napkins', 'whole wheat pasta', 'light cream', 'oil', 'olive oil'],
#   ['cake',
#    'oatmeal',
#    'mashed potato',
#    'pokemon shield',
#    'shrimp',
#    'pasta',
#    'cologne',
#    'chicken',
#    'tea'],
#   ['shampoo',
#    'cake',
#    'megaman zero 3',
#    'frozen vegetables',
#    'oil',
#    'fresh bread',
#    'mayonnaise',
#    'pancakes',
#    'muffins',
#    'escalope',
#    'cooking oil',
#    'tea'],
#   ['chocolate',
#    'napkins',
#    'cereals',
#    'black tea',
#    'pokemon sword',
#    'cologne',
#    'olive oil',
#    'tea'],
#   ['napkins',
#    'razor',
#    'strong cheese',
#    'oil',
#    'gums',
#    'tomatoes',
#    'pasta',
#    'babies food',
#    'pet food',
#    'cookies',
#    'cooking oil'],
#   ['candy bars', 'cake', 'oil', 'sandwich', 'ground beef', 'chicken', 'tea'],
#   ['candy bars', 'cake', 'cooking oil', 'ketchup'],
#   ['cake',
#    'french fries',
#    'oil',
#    'airpods',
#    'catfish',
#    'ratchet & clank',
#    'gums',
#    'tomatoes',
#    'carrots',
#    'spinach',
#    'cooking oil'],
#   ['bramble', 'oatmeal', 'cooking oil'],
#   ['candy bars',
#    'french fries',
#    'frozen vegetables',
#    'oil',
#    'ketchup',
#    'gums',
#    'pasta',
#    'sandwich',
#    'cologne',
#    'salad',
#    'tomato sauce',
#    'tea'],
#   ['candy bars',
#    'shallot',
#    'oil',
#    'gums',
#    'yogurt cake',
#    'metroid prime',
#    'phone car charger'],
#   ['napkins',
#    'spaghetti',
#    'gluten free bar',
#    'sparkling water',
#    'trout',
#    'nonfat milk',
#    'portal 2',
#    'toilet paper',
#    'tomato juice',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'oil', 'gums', 'ground beef', 'cookies'],
#   ['soda',
#    'cake',
#    'napkins',
#    'cotton buds',
#    'mashed potato',
#    'cooking oil',
#    'oil',
#    'pokemon sword',
#    'cream',
#    'gums',
#    'yogurt cake',
#    'zucchini'],
#   ['soup',
#    'napkins',
#    'hot dogs',
#    'oil',
#    'gums',
#    'muffins',
#    'yogurt cake',
#    'tea'],
#   ['fresh bread', 'soup', 'cotton buds', 'tea'],
#   ['shampoo',
#    'vacuum cleaner',
#    'napkins',
#    'oil',
#    'flax seed',
#    'pasta',
#    'burgers',
#    'light mayo',
#    'cooking oil',
#    'metroid fusion',
#    'tea'],
#   ['cake',
#    'iPad',
#    'spaghetti',
#    'mashed potato',
#    'cereals',
#    'ketchup',
#    'oil',
#    'honey',
#    'milk',
#    'pasta',
#    'cookies',
#    'megaman zero',
#    'cooking oil',
#    'tea'],
#   ['napkins',
#    'cottage cheese',
#    'oil',
#    'asparagus',
#    'muffins',
#    'melons',
#    'white wine',
#    'pasta',
#    'cooking oil',
#    'tea'],
#   ['shampoo',
#    'napkins',
#    'oil',
#    'low fat yogurt',
#    'cream',
#    'parmesan cheese',
#    'minecraft',
#    'pet food',
#    'herb & pepper',
#    'tea'],
#   ['soda',
#    'spaghetti',
#    'french fries',
#    'pokemon shield',
#    'champagne',
#    'yogurt cake',
#    'ratchet & clank 3'],
#   ['candy bars',
#    'chocolate',
#    'napkins',
#    'oil',
#    'bacon',
#    'toothpaste',
#    'cream',
#    'babies food',
#    'sandwich',
#    'burgers',
#    'mint green tea',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'turkey',
#    'oil',
#    'megaman zero 2',
#    'gums',
#    'tomatoes',
#    'milk',
#    'olive oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'oatmeal',
#    'phone charger',
#    'oil',
#    'melons',
#    'green beans',
#    'cooking oil',
#    'tea'],
#   ['oatmeal', 'hot dogs', 'oil', 'melons', 'barbecue sauce', 'tea'],
#   ['candy bars',
#    'shallot',
#    'eggplant',
#    'spaghetti',
#    'barbecue sauce',
#    'oil',
#    'almonds',
#    'yogurt cake',
#    'olive oil',
#    'butter',
#    'cat food',
#    'cooking oil'],
#   ['ketchup', 'oil'],
#   ['cider',
#    'soup',
#    'hot dogs',
#    'cottage cheese',
#    'oil',
#    'avocado',
#    'gums',
#    'pet food',
#    'ham',
#    'salmon',
#    'barbecue sauce'],
#   ['soup',
#    'oil',
#    'gums',
#    'muffins',
#    'extra dark chocolate',
#    'iMac',
#    'chicken',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'pokemon shield',
#    'cereals',
#    'gums',
#    'pancakes',
#    'ratchet & clank 2',
#    'babies food',
#    'pet food',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['dessert wine',
#    'cottage cheese',
#    'oil',
#    'gums',
#    'pepper',
#    'salt',
#    'herb & pepper',
#    'cooking oil',
#    'tea'],
#   ['oil', 'pepper', 'final fantasy XXII'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'oil',
#    'ketchup',
#    'parmesan cheese',
#    'babies food',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'shampoo', 'napkins', 'cream', 'gums', 'cooking oil', 'tea'],
#   ['candy bars',
#    'french fries',
#    'pokemon violet',
#    'oil',
#    'laptop',
#    'gluten free bar',
#    'megaman zero 4',
#    'vegetables mix',
#    'fresh bread',
#    'yogurt cake',
#    'water spray',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'napkins',
#    'rice',
#    'oil',
#    'portal 2',
#    'ground beef',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'whole wheat rice',
#    'butter',
#    'oil',
#    'fresh bread',
#    'milk',
#    'ground beef',
#    'pepper',
#    'megaman zero 2',
#    'red wine',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'shampoo',
#    'cake',
#    'oil',
#    'fromage blanc',
#    'chocolate bread',
#    'gums',
#    'whole weat flour',
#    'cooking oil',
#    'metroid fusion',
#    'tea'],
#   ['napkins',
#    'french fries',
#    'oil',
#    'fresh bread',
#    'muffins',
#    'pet food',
#    'half-life 2',
#    'pasta',
#    'chutney'],
#   ['cake',
#    'phone charger',
#    'french fries',
#    'oil',
#    'deodorant',
#    'sparkling water',
#    'pasta',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['oil', 'yogurt cake', 'deodorant', 'eggs'],
#   ['cotton buds',
#    'megaman zero 3',
#    'seabass',
#    'brownies',
#    'portal 2',
#    'cooking oil'],
#   ['cottage cheese',
#    'oil',
#    'ketchup',
#    'milk',
#    'carrots',
#    'muffins',
#    'babies food',
#    'toothpaste',
#    'mayonnaise',
#    'water spray',
#    'cooking oil',
#    'green grapes',
#    'tea'],
#   ['soup', 'soda', 'pokemon violet', 'milk', 'escalope', 'salmon'],
#   ['cider',
#    'whole wheat rice',
#    'ring light',
#    'ketchup',
#    'gums',
#    'muffins',
#    'salmon',
#    'chili',
#    'body spray',
#    'tea'],
#   ['frozen vegetables',
#    'oil',
#    'honey',
#    'melons',
#    'yogurt cake',
#    'toilet paper',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'oil',
#    'final fantasy XXII',
#    'energy drink',
#    'almonds',
#    'corn',
#    'cooking oil',
#    'tea'],
#   ['final fantasy XIX',
#    'cake',
#    'oil',
#    'gums',
#    'green beans',
#    'megaman zero',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'mint green tea',
#    'oil',
#    'french wine',
#    'whole weat flour',
#    'muffins',
#    'yogurt cake',
#    'olive oil',
#    'cooking oil',
#    'vacuum cleaner',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'meatballs',
#    'whole wheat rice',
#    'oatmeal',
#    'mineral water',
#    'oil',
#    'asparagus',
#    'pancakes',
#    'megaman zero 4',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'frozen vegetables',
#    'oil',
#    'toothpaste',
#    'muffins',
#    'cooking oil',
#    'green grapes',
#    'tea'],
#   ['cake', 'napkins', 'bacon', 'gums', 'pet food', 'cooking oil'],
#   ['candy bars', 'soup', 'cake', 'napkins', 'ketchup', 'oil', 'cooking oil'],
#   ['napkins', 'eggplant', 'french fries', 'ring light', 'oil', 'bacon'],
#   ['cake',
#    'grated cheese',
#    'frozen vegetables',
#    'oil',
#    'ketchup',
#    'muffins',
#    'chili',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['light cream',
#    'whole wheat rice',
#    'chicken',
#    'oil',
#    'portal',
#    'shower gel',
#    'honey',
#    'fresh bread',
#    'tomatoes',
#    'pet food',
#    'spinach',
#    'body spray',
#    'cooking oil',
#    'tea'],
#   ['napkins',
#    'oil',
#    'milk',
#    'muffins',
#    'pet food',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'turkey',
#    'pokemon shield',
#    'oil',
#    'ketchup',
#    'asparagus',
#    'fresh bread',
#    'gums',
#    'whole weat flour',
#    'pet food',
#    'tomato sauce',
#    'tea'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'soup',
#    'chicken',
#    'oil',
#    'cream',
#    'yogurt cake',
#    'phone car charger',
#    'olive oil',
#    'toilet paper',
#    'cooking oil'],
#   ['cake', 'pokemon shield', 'oil', 'gums', 'babies food', 'escalope'],
#   ['cake',
#    'napkins',
#    'oatmeal',
#    'oil',
#    'tomatoes',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['oil', 'muffins'],
#   ['soda',
#    'cake',
#    'tooth brush',
#    'eggplant',
#    'oil',
#    'bacon',
#    'final fantasy XXII',
#    'pasta',
#    'toilet paper',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['soup',
#    'protein bar',
#    'napkins',
#    'grated cheese',
#    'oil',
#    'strawberries',
#    'deodorant',
#    'asparagus',
#    'gluten free bar',
#    'fromage blanc',
#    'ketchup',
#    'gums',
#    'muffins',
#    'yogurt cake',
#    'ratchet & clank 2',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'chocolate',
#    'cake',
#    'napkins',
#    'spaghetti',
#    'rice',
#    'cottage cheese',
#    'oil',
#    'low fat yogurt',
#    'fresh bread',
#    'babies food',
#    'light mayo',
#    'chicken',
#    'tea'],
#   ['shallot',
#    'black tea',
#    'pokemon scarlet',
#    'vacuum cleaner',
#    'cooking oil',
#    'green grapes'],
#   ['napkins',
#    'strong cheese',
#    'oil',
#    'fromage blanc',
#    'gums',
#    'parmesan cheese',
#    'metroid prime',
#    'cookies',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'whole wheat rice',
#    'ring light',
#    'fresh bread',
#    'cream',
#    'milk',
#    'mint green tea'],
#   ['napkins',
#    'hot dogs',
#    'rice',
#    'oil',
#    'avocado',
#    'ketchup',
#    'asparagus',
#    'flax seed',
#    'tomatoes',
#    'tea'],
#   ['candy bars', 'mayonnaise', 'portal', 'tea'],
#   ['candy bars',
#    'shampoo',
#    'cake',
#    'laptop',
#    'airpods',
#    'green beans',
#    'milk',
#    'parmesan cheese',
#    'muffins',
#    'pet food',
#    'ground beef',
#    'eggs',
#    'salmon',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'cereals',
#    'oil',
#    'gums',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'oatmeal',
#    'mashed potato',
#    'mint green tea',
#    'turkey',
#    'oil',
#    'toothpaste',
#    'green tea',
#    'ground beef',
#    'vacuum cleaner',
#    'cooking oil'],
#   ['oatmeal',
#    'corn',
#    'cookies',
#    'bluetooth headphones',
#    'cooking oil',
#    'metroid fusion'],
#   ['oil',
#    'avocado',
#    'fresh bread',
#    'white wine',
#    'phone car charger',
#    'chutney',
#    'tea'],
#   ['eggplant',
#    'ketchup',
#    'oil',
#    'deodorant',
#    'gums',
#    'pancakes',
#    'almonds',
#    'pet food',
#    'butter',
#    'cooking oil'],
#   ['candy bars',
#    'napkins',
#    'airpods',
#    'oil',
#    'fresh bread',
#    'yogurt cake',
#    'escalope',
#    'pepper',
#    'megaman zero',
#    'butter',
#    'herb & pepper',
#    'cooking oil'],
#   ['candy bars',
#    'napkins',
#    'meatballs',
#    'razor',
#    'french fries',
#    'mineral water',
#    'oil',
#    'fromage blanc',
#    'iMac',
#    'cooking oil',
#    'tea'],
#   ['mint green tea',
#    'oil',
#    'gums',
#    'escalope',
#    'half-life 2',
#    'extra dark chocolate',
#    'olive oil'],
#   ['candy bars',
#    'soup',
#    'napkins',
#    'rice',
#    'pokemon shield',
#    'oil',
#    'shower gel',
#    'low fat yogurt',
#    'melons',
#    'herb & pepper'],
#   ['shampoo',
#    'candy bars',
#    'cake',
#    'spaghetti',
#    'oil',
#    'portal',
#    'fresh bread',
#    'milk',
#    'babies food',
#    'cologne',
#    'light mayo',
#    'cooking oil',
#    'mushroom cream sauce',
#    'tea'],
#   ['oil', 'dog food', 'muffins', 'babies food', 'chutney', 'cooking oil'],
#   ['candy bars',
#    'final fantasy XIX',
#    'hot dogs',
#    'turkey',
#    'cereals',
#    'oil',
#    'strawberries',
#    'minecraft',
#    'olive oil',
#    'butter',
#    'ratchet & clank 2',
#    'tea'],
#   ['meatballs',
#    'eggplant',
#    'catfish',
#    'ratchet & clank 3',
#    'body spray',
#    'cooking oil',
#    'metroid fusion',
#    'tea'],
#   ['yams',
#    'oil',
#    'fresh bread',
#    'phone car charger',
#    'chicken',
#    'cooking oil',
#    'tea'],
#   ['cake', 'oil', 'tea'],
#   ['oil', 'strawberries', 'avocado', 'asparagus', 'mayonnaise'],
#   ['shallot',
#    'oil',
#    'gadget for tiktok streaming',
#    'pet food',
#    'portal 2',
#    'half-life: alyx'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'mashed potato',
#    'cooking oil',
#    'beer',
#    'oil',
#    'bacon',
#    'mayonnaise',
#    'gums',
#    'final fantasy XX',
#    'light mayo',
#    'tomato sauce',
#    'chocolate bread',
#    'cauliflower',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'oatmeal',
#    'frozen vegetables',
#    'oil',
#    'deodorant',
#    'gums',
#    'mayonnaise',
#    'yogurt cake',
#    'half-life: alyx',
#    'light mayo',
#    'tomato juice',
#    'cooking oil'],
#   ['cake',
#    'mashed potato',
#    'oil',
#    'gums',
#    'melons',
#    'cookies',
#    'salad',
#    'tea'],
#   ['spaghetti',
#    'french fries',
#    'oil',
#    'milk',
#    'gums',
#    'melons',
#    'corn',
#    'salmon',
#    'cookies',
#    'megaman zero',
#    'cooking oil',
#    'green grapes',
#    'tea'],
#   ['cake',
#    'oil',
#    'vegetables mix',
#    'fresh bread',
#    'energy drink',
#    'muffins',
#    'extra dark chocolate',
#    'spinach',
#    'green grapes'],
#   ['cake',
#    'french fries',
#    'oil',
#    'deodorant',
#    'red wine',
#    'milk',
#    'gums',
#    'cream',
#    'pancakes',
#    'muffins',
#    'pepper',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['meatballs',
#    'napkins',
#    'cotton buds',
#    'spaghetti',
#    'oil',
#    'gums',
#    'milk',
#    'final fantasy XX',
#    'tea'],
#   ['bramble', 'cake', 'rice', 'fresh bread', 'cologne', 'chocolate bread'],
#   ['cake',
#    'whole wheat pasta',
#    'oil',
#    'french wine',
#    'bacon',
#    'gums',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'whole wheat rice',
#    'rice',
#    'french fries',
#    'oil',
#    'final fantasy XXII',
#    'fresh bread',
#    'whole weat flour',
#    'parmesan cheese',
#    'spinach'],
#   ['soup', 'oil', 'pet food', 'bluetooth headphones'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'whole wheat pasta',
#    'oil',
#    'asparagus',
#    'fresh bread',
#    'pet food',
#    'blueberries',
#    'corn',
#    'ground beef',
#    'toilet paper',
#    'cooking oil',
#    'tea'],
#   ['pickles',
#    'grated cheese',
#    'oil',
#    'tomatoes',
#    'babies food',
#    'metroid prime',
#    'sandwich',
#    'french wine'],
#   ['candy bars',
#    'cake',
#    'turkey',
#    'oil',
#    'fromage blanc',
#    'fresh bread',
#    'gums',
#    'muffins',
#    'fresh tuna'],
#   ['candy bars',
#    'laptop',
#    'oil',
#    'cream',
#    'whole weat flour',
#    'pet food',
#    'megaman zero',
#    'cooking oil'],
#   ['fresh bread', 'oil', 'napkins', 'yogurt cake'],
#   ['cake', 'shower gel', 'babies food', 'tomato sauce', 'zucchini', 'tea'],
#   ['cider',
#    'oatmeal',
#    'cottage cheese',
#    'oil',
#    'ketchup',
#    'shower gel',
#    'blueberries',
#    'cookies',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['oil', 'babies food', 'cooking oil', 'grated cheese'],
#   ['candy bars',
#    'oil',
#    'fromage blanc',
#    'ketchup',
#    'catfish',
#    'mayonnaise',
#    'toothpaste',
#    'shrimp',
#    'blueberries',
#    'cooking oil'],
#   ['dessert wine', 'gums'],
#   ['shampoo',
#    'cake',
#    'eggplant',
#    'french fries',
#    'oil',
#    'champagne',
#    'mayonnaise',
#    'green beans'],
#   ['barbecue sauce',
#    'frozen smoothie',
#    'oil',
#    'shower gel',
#    'tomatoes',
#    'parmesan cheese',
#    'cookies',
#    'megaman zero 4',
#    'cat food',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'cereals',
#    'oil',
#    'ketchup',
#    'gums',
#    'babies food',
#    'pet food',
#    'half-life: alyx',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'cologne', 'gums', 'cookies', 'cooking oil'],
#   ['cake',
#    'hot dogs',
#    'cotton buds',
#    'whole wheat rice',
#    'oil',
#    'fromage blanc',
#    'ketchup',
#    'asparagus',
#    'sparkling water',
#    'pasta',
#    'tea'],
#   ['candy bars',
#    'antioxydant juice',
#    'gums',
#    'yogurt cake',
#    'extra dark chocolate',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'oil',
#    'gums',
#    'shrimp',
#    'muffins',
#    'babies food',
#    'pet food',
#    'minecraft',
#    'extra dark chocolate',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['samsung galaxy 10',
#    'shower gel',
#    'pancakes',
#    'cream',
#    'salmon',
#    'cauliflower',
#    'tea'],
#   ['soup', 'oil', 'fresh bread', 'cream', 'mint'],
#   ['candy bars',
#    'oil',
#    'asparagus',
#    'final fantasy XXII',
#    'gums',
#    'extra dark chocolate',
#    'pepper',
#    'megaman zero 4',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'napkins',
#    'beer',
#    'pokemon shield',
#    'oil',
#    'gluten free bar',
#    'parmesan cheese',
#    'final fantasy XX',
#    'butter',
#    'tea'],
#   ['soda',
#    'cake',
#    'whole wheat rice',
#    'spaghetti',
#    'ring light',
#    'oil',
#    'gadget for tiktok streaming',
#    'half-life: alyx',
#    'cooking oil',
#    'cauliflower',
#    'tea'],
#   ['pokemon shield',
#    'cereals',
#    'fresh bread',
#    'gums',
#    'milk',
#    'babies food',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'napkins',
#    'antioxydant juice',
#    'cologne',
#    'samsung galaxy 10',
#    'ketchup',
#    'oil',
#    'airpods',
#    'burgers',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'cake', 'oil', 'cooking oil'],
#   ['cake',
#    'napkins',
#    'spaghetti',
#    'antioxydant juice',
#    'phone charger',
#    'pokemon shield',
#    'milk',
#    'trout',
#    'muffins',
#    'cooking oil'],
#   ['hot dogs', 'oil', 'gums', 'cream', 'ratchet & clank 2'],
#   ['soup',
#    'cake',
#    'megaman zero 3',
#    'oil',
#    'vegetables mix',
#    'fresh bread',
#    'gums',
#    'muffins',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['tooth brush',
#    'whole wheat rice',
#    'spaghetti',
#    'antioxydant juice',
#    'frozen vegetables',
#    'oil',
#    'ketchup',
#    'pokemon scarlet',
#    'tomatoes',
#    'green tea',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'hot dogs',
#    'eggplant',
#    'frozen vegetables',
#    'oil',
#    'champagne',
#    'gums',
#    'muffins',
#    'cookies',
#    'olive oil',
#    'herb & pepper'],
#   ['pickles',
#    'french fries',
#    'strong cheese',
#    'oil',
#    'fresh bread',
#    'cream',
#    'mayonnaise',
#    'muffins',
#    'cookies',
#    'olive oil',
#    'cooking oil'],
#   ['turkey', 'cake', 'oil', 'french wine'],
#   ['candy bars',
#    'dessert wine',
#    'iPad',
#    'rice',
#    'oil',
#    'pet food',
#    'cooking oil'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'french fries',
#    'cereals',
#    'oil',
#    'fresh bread',
#    'pasta',
#    'muffins',
#    'babies food',
#    'cookies',
#    'tomato sauce'],
#   ['soup',
#    'grated cheese',
#    'oil',
#    'catfish',
#    'shower gel',
#    'sandwich',
#    'cooking oil',
#    'metroid fusion'],
#   ['black beer',
#    'oil',
#    'ketchup',
#    'deodorant',
#    'honey',
#    'parmesan cheese',
#    'pasta',
#    'cookies',
#    'olive oil',
#    'cooking oil'],
#   ['black beer',
#    'soup',
#    'cake',
#    'phone charger',
#    'frozen vegetables',
#    'oil',
#    'gums',
#    'eggs',
#    'olive oil',
#    'cooking oil'],
#   ['chocolate',
#    'soup',
#    'napkins',
#    'rice',
#    'cottage cheese',
#    'grated cheese',
#    'oil',
#    'muffins',
#    'sandwich',
#    'burgers',
#    'ratchet & clank 2'],
#   ['shampoo', 'mayonnaise', 'ground beef'],
#   ['candy bars',
#    'energy bar',
#    'french fries',
#    'ketchup',
#    'deodorant',
#    'pokemon sword',
#    'muffins',
#    'pet food',
#    'barbecue sauce',
#    'cooking oil'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'cotton buds',
#    'oil',
#    'cream',
#    'muffins',
#    'cooking oil',
#    'metroid fusion',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'iPad',
#    'cereals',
#    'oil',
#    'canned_tuna',
#    'cologne',
#    'cooking oil'],
#   ['candy bars',
#    'yams',
#    'napkins',
#    'oil',
#    'bacon',
#    'ketchup',
# ...
#    'light mayo',
#    'tea'],
#   ['olive oil',
#    'oil',
#    'dog food',
#    'milk',
#    'body spray',
#    'bluetooth headphones',
#    'cooking oil',
#    'tea'],
#   ['oil', 'milk', 'gums', 'tomato juice', 'cooking oil'],
#   ['candy bars',
#    'cake',
#    'rice',
#    'olive oil',
#    'fresh bread',
#    'carrots',
#    'muffins',
#    'toilet paper',
#    'cooking oil'],
#   ['cotton buds',
#    'cereals',
#    'oil',
#    'asparagus',
#    'sparkling water',
#    'yogurt cake',
#    'canned_tuna',
#    'ground beef',
#    'cooking oil',
#    'mushroom cream sauce'],
#   ['candy bars',
#    'cake',
#    'cottage cheese',
#    'oil',
#    'gadget for tiktok streaming',
#    'champagne',
#    'melons',
#    'butter',
#    'cooking oil'],
#   ['yams',
#    'napkins',
#    'mineral water',
#    'oil',
#    'hand protein bar',
#    'megaman zero 2',
#    'tea'],
#   ['soup',
#    'napkins',
#    'spaghetti',
#    'oatmeal',
#    'cottage cheese',
#    'oil',
#    'fresh bread',
#    'pet food',
#    'yogurt cake',
#    'cologne',
#    'salad',
#    'half-life: alyx'],
#   ['oil', 'muffins'],
#   ['candy bars', 'pickles', 'ketchup', 'oil', 'burgers', 'body spray', 'tea'],
#   ['candy bars',
#    'cake',
#    'cotton buds',
#    'mashed potato',
#    'oil',
#    'strawberries',
#    'pokemon scarlet',
#    'pet food',
#    'salad',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'oil',
#    'gums',
#    'parmesan cheese',
#    'milk',
#    'pepper',
#    'cookies',
#    'cooking oil'],
#   ['shampoo',
#    'candy bars',
#    'cake',
#    'cotton buds',
#    'turkey',
#    'oil',
#    'fromage blanc',
#    'gums',
#    'whole weat flour',
#    'muffins',
#    'tea',
#    'eggs',
#    'cologne',
#    'body spray',
#    'salt'],
#   ['pickles',
#    'cake',
#    'rice',
#    'oil',
#    'shower gel',
#    'cream',
#    'yogurt cake',
#    'pet food',
#    'cologne',
#    'tea'],
#   ['iPad',
#    'napkins',
#    'beer',
#    'chocolate bread',
#    'fresh bread',
#    'mayonnaise',
#    'sandwich',
#    'cooking oil',
#    'green grapes',
#    'tea'],
#   ['cake', 'oil', 'pokemon scarlet', 'salad', 'cooking oil', 'tea'],
#   ['black beer', 'french fries', 'oil', 'muffins', 'cooking oil'],
#   ['gums', 'oil', 'spinach'],
#   ['pickles', 'grated cheese', 'oil', 'yogurt cake', 'cooking oil', 'tea'],
#   ['candy bars', 'oil', 'pokemon shield'],
#   ['gums', 'oil', 'yogurt cake', 'cooking oil'],
#   ['soup', 'oil', 'pet food', 'white wine', 'chili', 'cooking oil'],
#   ['hot dogs', 'napkins', 'oil', 'fresh bread', 'fresh tuna', 'tea'],
#   ['shampoo',
#    'tooth brush',
#    'frozen smoothie',
#    'oil',
#    'gums',
#    'shrimp',
#    'tea'],
#   ['soda',
#    'cake',
#    'rice',
#    'phone charger',
#    'french fries',
#    'oil',
#    'avocado',
#    'deodorant',
#    'cologne',
#    'bluetooth headphones'],
#   ['shampoo',
#    'soup',
#    'spaghetti',
#    'ketchup',
#    'oil',
#    'gums',
#    'muffins',
#    'megaman zero 4',
#    'cooking oil'],
#   ['shrimp', 'oil', 'herb & pepper'],
#   ['candy bars',
#    'soup',
#    'whole wheat pasta',
#    'spaghetti',
#    'french fries',
#    'bacon',
#    'oil',
#    'final fantasy XXII',
#    'fresh bread',
#    'gums',
#    'milk',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'oatmeal',
#    'ketchup',
#    'oil',
#    'ham',
#    'sandwich',
#    'eggs',
#    'cooking oil',
#    'tea'],
#   ['whole wheat pasta',
#    'cereals',
#    'oil',
#    'pokemon scarlet',
#    'gums',
#    'toothpaste',
#    'melons',
#    'pet food',
#    'escalope',
#    'zucchini'],
#   ['cake',
#    'whole wheat rice',
#    'rice',
#    'oil',
#    'strawberries',
#    'parmesan cheese',
#    'sandwich',
#    'cookies',
#    'salad',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'napkins',
#    'eggplant',
#    'rice',
#    'frozen smoothie',
#    'tomatoes',
#    'melons',
#    'corn',
#    'cooking oil',
#    'tea'],
#   ['yams', 'cake', 'oatmeal', 'iPad', 'whole weat flour', 'sandwich', 'razor'],
#   ['cake',
#    'iPad',
#    'oil',
#    'dog food',
#    'ham',
#    'sandwich',
#    'half-life: alyx',
#    'chicken',
#    'tomato sauce',
#    'cooking oil',
#    'mushroom cream sauce',
#    'tea'],
#   ['soup',
#    'cake',
#    'iPad',
#    'antioxydant juice',
#    'gums',
#    'toothpaste',
#    'almonds',
#    'salmon',
#    'cookies',
#    'chocolate bread',
#    'tea'],
#   ['cake', 'muffins'],
#   ['gadget for tiktok streaming',
#    'black tea',
#    'whole weat flour',
#    'canned_tuna',
#    'ratchet & clank 2',
#    'cooking oil',
#    'tea'],
#   ['cake', 'napkins', 'spaghetti', 'tea'],
#   ['soup',
#    'cake',
#    'napkins',
#    'soda',
#    'cereals',
#    'oil',
#    'gums',
#    'tomatoes',
#    'muffins',
#    'megaman zero 2',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'meatballs',
#    'french fries',
#    'strong cheese',
#    'oil',
#    'asparagus',
#    'catfish',
#    'shower gel',
#    'gums',
#    'phone car charger',
#    'cookies',
#    'tea'],
#   ['candy bars',
#    'cotton buds',
#    'ketchup',
#    'oil',
#    'asparagus',
#    'gums',
#    'nonfat milk',
#    'babies food',
#    'tea'],
#   ['yams',
#    'oil',
#    'fresh bread',
#    'cream',
#    'whole weat flour',
#    'hand protein bar',
#    'blueberries',
#    'cooking oil'],
#   ['candy bars',
#    'dessert wine',
#    'bramble',
#    'oatmeal',
#    'rice',
#    'razor',
#    'french fries',
#    'oil',
#    'seabass',
#    'avocado',
#    'megaman zero',
#    'babies food',
#    'megaman zero 2',
#    'cat food',
#    'cooking oil',
#    'tea'],
#   ['cookies', 'escalope'],
#   ['candy bars', 'cake', 'spaghetti'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'napkins',
#    'frozen vegetables',
#    'oil',
#    'whole weat flour',
#    'cologne'],
#   ['cider', 'french fries', 'fresh bread', 'mayonnaise', 'gums', 'sandwich'],
#   ['soup', 'oil', 'milk', 'tomato juice', 'cooking oil'],
#   ['fresh bread', 'cake', 'cooking oil'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'hot dogs',
#    'antioxydant juice',
#    'frozen vegetables',
#    'ketchup',
#    'oil',
#    'gums',
#    'toothpaste',
#    'cooking oil',
#    'tea'],
#   ['mineral water',
#    'oil',
#    'frozen vegetables',
#    'strawberries',
#    'sparkling water',
#    'gums',
#    'megaman zero',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'turkey',
#    'oil',
#    'deodorant',
#    'light mayo',
#    'cat food'],
#   ['cake',
#    'napkins',
#    'french fries',
#    'pokemon violet',
#    'oil',
#    'sparkling water',
#    'gums',
#    'muffins',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'oil',
#    'strawberries',
#    'milk',
#    'tomatoes',
#    'muffins',
#    'olive oil',
#    'cooking oil'],
#   ['napkins', 'cotton buds', 'oil', 'gums', 'cream', 'eggs', 'cooking oil'],
#   ['cake',
#    'rice',
#    'oil',
#    'whole weat flour',
#    'muffins',
#    'brownies',
#    'blueberries',
#    'eggs'],
#   ['shampoo',
#    'cider',
#    'shallot',
#    'airpods',
#    'oil',
#    'olive oil',
#    'cooking oil'],
#   ['candy bars', 'napkins', 'oil', 'ketchup', 'cookies', 'cooking oil', 'tea'],
#   ['cake',
#    'mineral water',
#    'ketchup',
#    'gums',
#    'pet food',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['oatmeal',
#    'pokemon violet',
#    'final fantasy XXII',
#    'pokemon scarlet',
#    'whole weat flour',
#    'pet food',
#    'light mayo',
#    'tea'],
#   ['cake',
#    'oatmeal',
#    'cereals',
#    'oil',
#    'asparagus',
#    'whole weat flour',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'pokemon violet',
#    'bacon',
#    'oil',
#    'black tea',
#    'gums',
#    'pasta',
#    'pet food',
#    'canned_tuna',
#    'cookies',
#    'olive oil'],
#   ['cider',
#    'ring light',
#    'asparagus',
#    'gums',
#    'parmesan cheese',
#    'zucchini',
#    'cauliflower'],
#   ['candy bars',
#    'cottage cheese',
#    'oil',
#    'catfish',
#    'muffins',
#    'babies food',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'whole wheat rice',
#    'napkins',
#    'chutney',
#    'frozen vegetables',
#    'oil',
#    'fromage blanc',
#    'fresh bread',
#    'ground beef',
#    'bluetooth headphones',
#    'cooking oil',
#    'salt'],
#   ['cake',
#    'napkins',
#    'cottage cheese',
#    'strong cheese',
#    'oil',
#    'flax seed',
#    'muffins',
#    'minecraft',
#    'yogurt cake',
#    'cooking oil',
#    'tea'],
#   ['shampoo',
#    'cake',
#    'oil',
#    'cream',
#    'parmesan cheese',
#    'muffins',
#    'gums',
#    'escalope',
#    'cooking oil',
#    'tea'],
#   ['shampoo',
#    'candy bars',
#    'soup',
#    'napkins',
#    'oatmeal',
#    'ketchup',
#    'gums',
#    'melons',
#    'ratchet & clank 3',
#    'cookies',
#    'chicken',
#    'butter',
#    'cooking oil',
#    'tea'],
#   ['cake', 'napkins', 'oil', 'gluten free bar', 'pokemon sword', 'tea'],
#   ['candy bars',
#    'cake',
#    'strong cheese',
#    'oil',
#    'airpods',
#    'dog food',
#    'asparagus',
#    'megaman zero',
#    'yogurt cake',
#    'portal 2',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['cotton buds',
#    'oil',
#    'toothpaste',
#    'gums',
#    'cream',
#    'milk',
#    'ham',
#    'salmon',
#    'iMac',
#    'olive oil',
#    'toilet paper',
#    'cooking oil'],
#   ['soup',
#    'cake',
#    'oil',
#    'gums',
#    'cookies',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['soda',
#    'soup',
#    'rice',
#    'strong cheese',
#    'oil',
#    'fromage blanc',
#    'asparagus',
#    'fresh bread',
#    'mayonnaise',
#    'pet food',
#    'green beans',
#    'megaman zero 4',
#    'mint',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'oil',
#    'fromage blanc',
#    'champagne',
#    'muffins',
#    'ham',
#    'cookies',
#    'cooking oil'],
#   ['candy bars',
#    'cake',
#    'napkins',
#    'oil',
#    'catfish',
#    'gums',
#    'pasta',
#    'yogurt cake',
#    'minecraft',
#    'sandwich',
#    'corn',
#    'portal 2',
#    'cooking oil',
#    'tea'],
#   ['candy bars', 'oil'],
#   ['spaghetti',
#    'oil',
#    'cream',
#    'trout',
#    'pasta',
#    'yogurt cake',
#    'escalope',
#    'corn',
#    'muffins',
#    'body spray',
#    'cooking oil'],
#   ['olive oil', 'bacon', 'fromage blanc', 'tea'],
#   ['cake',
#    'cat food',
#    'olive oil',
#    'oil',
#    'gums',
#    'cream',
#    'chicken',
#    'tomato sauce',
#    'cooking oil'],
#   ['napkins',
#    'hot dogs',
#    'oil',
#    'black tea',
#    'fresh bread',
#    'gums',
#    'toilet paper',
#    'green grapes'],
#   ['antioxydant juice',
#    'oil',
#    'honey',
#    'cream',
#    'muffins',
#    'escalope',
#    'cologne'],
#   ['cider',
#    'cake',
#    'oil',
#    'vegetables mix',
#    'milk',
#    'yogurt cake',
#    'final fantasy XX'],
#   ['candy bars',
#    'tooth brush',
#    'cake',
#    'napkins',
#    'yams',
#    'mashed potato',
#    'olive oil',
#    'oil',
#    'seabass',
#    'chocolate bread',
#    'gums',
#    'carrots',
#    'sandwich',
#    'iMac',
#    'body spray',
#    'cooking oil'],
#   ['candy bars',
#    'cake',
#    'oil',
#    'ketchup',
#    'fresh bread',
#    'cream',
#    'carrots',
#    'muffins',
#    'ratchet & clank',
#    'pet food',
#    'cooking oil',
#    'tea'],
#   ['napkins',
#    'energy bar',
#    'oil',
#    'seabass',
#    'cream',
#    'milk',
#    'yogurt cake',
#    'olive oil',
#    'cooking oil',
#    'cauliflower'],
#   ['candy bars', 'oil', 'muffins', 'tea'],
#   ['candy bars',
#    'soup',
#    'bramble',
#    'whole wheat rice',
#    'oatmeal',
#    'oil',
#    'black tea',
#    'dog food',
#    'gums',
#    'muffins',
#    'toilet paper',
#    'cauliflower',
#    'tea'],
#   ['oil', 'rice', 'tea'],
#   ['olive oil', 'salt'],
#   ['candy bars',
#    'soda',
#    'napkins',
#    'rice',
#    'laptop',
#    'oil',
#    'whole weat flour',
#    'muffins',
#    'tomatoes',
#    'extra dark chocolate',
#    'toilet paper',
#    'green grapes',
#    'tea'],
#   ['black beer',
#    'soda',
#    'cake',
#    'turkey',
#    'oil',
#    'asparagus',
#    'escalope',
#    'ratchet & clank 3',
#    'bluetooth headphones'],
#   ['bramble',
#    'hot dogs',
#    'oil',
#    'flax seed',
#    'muffins',
#    'pasta',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['cake', 'cottage cheese', 'oil', 'cologne', 'cooking oil', 'tea'],
#   ['cake',
#    'rice',
#    'french fries',
#    'oil',
#    'parmesan cheese',
#    'body spray',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'soup',
#    'napkins',
#    'whole wheat rice',
#    'cereals',
#    'oil',
#    'fresh bread',
#    'gums',
#    'megaman zero 2',
#    'cooking oil',
#    'tea'],
#   ['strong cheese',
#    'oil',
#    'asparagus',
#    'half-life 2',
#    'cookies',
#    'cooking oil',
#    'tea'],
#   ['oil', 'cookies', 'water spray', 'tomato sauce', 'tea'],
#   ['butter',
#    'yogurt cake',
#    'ground beef',
#    'phone car charger',
#    'mint',
#    'red wine',
#    'tea'],
#   ['tooth brush',
#    'hot dogs',
#    'napkins',
#    'rice',
#    'frozen vegetables',
#    'toilet paper',
#    'herb & pepper',
#    'tea'],
#   ['shampoo',
#    'candy bars',
#    'oil',
#    'cream',
#    'pet food',
#    'babies food',
#    'red wine',
#    'french wine'],
#   ['candy bars',
#    'cake',
#    'rice',
#    'bacon',
#    'oil',
#    'fresh bread',
#    'whole weat flour',
#    'pasta',
#    'brownies',
#    'half-life: alyx',
#    'eggs',
#    'body spray',
#    'cooking oil',
#    'tea'],
#   ['soup',
#    'cake',
#    'napkins',
#    'beer',
#    'french fries',
#    'oil',
#    'deodorant',
#    'spinach',
#    'cream',
#    'babies food',
#    'yogurt cake',
#    'final fantasy XX',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'oil',
#    'whole weat flour',
#    'babies food',
#    'minecraft',
#    'ground beef',
#    'phone car charger',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['shampoo',
#    'soup',
#    'cake',
#    'pickles',
#    'hot dogs',
#    'grated cheese',
#    'gums',
#    'tomatoes',
#    'muffins',
#    'red wine',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'iPad',
#    'pokemon shield',
#    'ground beef',
#    'olive oil',
#    'cooking oil'],
#   ['napkins',
#    'french fries',
#    'frozen smoothie',
#    'oil',
#    'ketchup',
#    'turkey',
#    'toothpaste',
#    'carrots',
#    'muffins',
#    'salmon',
#    'megaman zero'],
#   ['soup',
#    'cake',
#    'oil',
#    'airpods',
#    'gums',
#    'muffins',
#    'metroid prime',
#    'eggs',
#    'cooking oil',
#    'tea'],
#   ['cake', 'hot dogs', 'oil', 'ratchet & clank 2', 'cooking oil', 'tea'],
#   ['napkins',
#    'oil',
#    'avocado',
#    'low fat yogurt',
#    'gums',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'iPad',
#    'cooking oil',
#    'oil',
#    'seabass',
#    'gums',
#    'toothpaste',
#    'yogurt cake',
#    'ratchet & clank 3',
#    'zucchini'],
#   ['yams',
#    'soup',
#    'cake',
#    'meatballs',
#    'cereals',
#    'oil',
#    'fresh bread',
#    'milk',
#    'babies food',
#    'pepper',
#    'phone car charger',
#    'megaman zero 4',
#    'cooking oil',
#    'tea'],
#   ['soup', 'oil'],
#   ['pickles',
#    'soup',
#    'tooth brush',
#    'cake',
#    'strong cheese',
#    'oil',
#    'ketchup',
#    'catfish',
#    'toothpaste',
#    'whole weat flour',
#    'muffins',
#    'babies food',
#    'cooking oil'],
#   ['candy bars',
#    'cake',
#    'cereals',
#    'oil',
#    'fresh bread',
#    'muffins',
#    'burgers',
#    'body spray'],
#   ['cake',
#    'french fries',
#    'oil',
#    'dog food',
#    'gums',
#    'vacuum cleaner',
#    'red wine'],
#   ['mineral water', 'muffins'],
#   ['candy bars',
#    'cake',
#    'light cream',
#    'grated cheese',
#    'laptop',
#    'oil',
#    'asparagus',
#    'shrimp',
#    'milk',
#    'almonds',
#    'corn',
#    'green grapes'],
#   ['candy bars',
#    'soup',
#    'pickles',
#    'phone charger',
#    'razor',
#    'frozen vegetables',
#    'ketchup',
#    'fresh bread',
#    'whole weat flour',
#    'corn',
#    'ratchet & clank 3',
#    'cookies',
#    'toilet paper',
#    'tomato sauce',
#    'cooking oil',
#    'tea'],
#   ['candy bars',
#    'cake',
#    'turkey',
#    'cereals',
#    'oil',
#    'megaman zero 2',
#    'cooking oil',
#    'tea'],
#   ['gums', 'pasta'],
#   ['candy bars',
#    'soup',
#    'cake',
#    'napkins',
#    'cotton buds',
#    'oatmeal',
#    'oil',
#    'gums',
#    'nonfat milk',
#    'mint',
#    'tea'],
#   ['cake',
#    'cotton buds',
#    'oil',
#    'cream',
#    'whole weat flour',
#    'babies food',
#    'cooking oil'],
#   ['soup',
#    'napkins',
#    'spaghetti',
#    'rice',
#    'cotton buds',
#    'french fries',
#    'oil',
#    'sparkling water',
#    'whole weat flour',
#    'muffins',
#    'ground beef',
#    'tomato sauce',
#    'fresh tuna',
#    'cauliflower',
#    'tea'],
#   ['bramble',
#    'candy bars',
#    'strong cheese',
#    'cereals',
#    'oil',
#    'pokemon shield',
#    'gadget for tiktok streaming',
#    'gums',
#    'pasta',
#    'minecraft',
#    'olive oil',
#    'toilet paper',
#    'tea'],
#   ['meatballs',
#    'turkey',
#    'megaman zero',
#    'corn',
#    'yogurt cake',
#    'ham',
#    'olive oil',
#    'cooking oil',
#    'tea'],
#   ['cake',
#    'rice',
#    'turkey',
#    'oil',
#    'final fantasy XXII',
#    'fresh bread',
#    'olive oil',
#    'mint',
#    'cooking oil'],
#   ['candy bars',
#    'napkins',
#    'cotton buds',
#    'strong cheese',
#    'ketchup',
#    'oil',
#    'gums',
#    'pancakes',
#    'cooking oil',
#    'tea'],
#   ...])

# %%
frequent_itemsets, rules = apriori_algorithm(df_items2, min_support=0.2, metric='confidence', confidence_threshold = 0.5)

# %%
rules
# Out:
#            antecedents    consequents  antecedent support  consequent support  \
# 0               (cake)  (cooking oil)            0.407288            0.535324
# 1               (cake)          (oil)            0.407288            0.762587
# 2               (cake)          (tea)            0.407288            0.530748
# 3         (candy bars)          (oil)            0.324023            0.762587
# 4                (oil)  (cooking oil)            0.762587            0.535324
# 5        (cooking oil)          (oil)            0.535324            0.762587
# 6        (cooking oil)          (tea)            0.535324            0.530748
# 7                (tea)  (cooking oil)            0.530748            0.535324
# 8               (gums)          (oil)            0.278547            0.762587
# 9                (oil)          (tea)            0.762587            0.530748
# 10               (tea)          (oil)            0.530748            0.762587
# 11  (oil, cooking oil)          (tea)            0.428647            0.530748
# 12          (oil, tea)  (cooking oil)            0.426828            0.535324
# 13  (tea, cooking oil)          (oil)            0.304542            0.762587
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 0   0.233071    0.572252  1.068981               1.0  0.015040    1.086330
# 1   0.329480    0.808961  1.060812               1.0  0.018888    1.242750
# 2   0.233717    0.573837  1.081186               1.0  0.017550    1.101109
# 3   0.261237    0.806230  1.057230               1.0  0.014141    1.225231
# 4   0.428647    0.562096  1.050010               1.0  0.020416    1.061136
# 5   0.428647    0.800723  1.050010               1.0  0.020416    1.191377
# 6   0.304542    0.568892  1.071869               1.0  0.020420    1.088480
# 7   0.304542    0.573798  1.071869               1.0  0.020420    1.090270
# 8   0.225091    0.808089  1.059669               1.0  0.012675    1.237104
# 9   0.426828    0.559711  1.054570               1.0  0.022087    1.065782
# 10  0.426828    0.804201  1.054570               1.0  0.022087    1.212538
# 11  0.253081    0.590418  1.112426               1.0  0.025577    1.145685
# 12  0.253081    0.592934  1.107616               1.0  0.024589    1.141523
# 13  0.253081    0.831021  1.089740               1.0  0.020841    1.404990
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0        0.108872  0.328482   0.079469    0.503817
# 1        0.096718  0.392054   0.195333    0.620509
# 2        0.126688  0.331834   0.091825    0.507095
# 3        0.080080  0.316508   0.183827    0.574398
# 4        0.200612  0.493115   0.057613    0.681410
# 5        0.102497  0.493115   0.160635    0.681410
# 6        0.144294  0.399908   0.081287    0.571345
# 7        0.142887  0.399908   0.082796    0.571345
# 8        0.078050  0.275832   0.191660    0.551629
# 9        0.217960  0.492585   0.061722    0.681956
# 10       0.110275  0.492585   0.175284    0.681956
# 11       0.176885  0.358312   0.127160    0.533628
# 12       0.169512  0.356918   0.123977    0.532847
# 13       0.118411  0.310892   0.288251    0.581446

# %% [markdown]
# ## Eclat Algorithm

# %%
items_list2
# Out:
# [['soup',
#   'shallot',
#   'cake',
#   'fresh bread',
#   'cream',
#   'carrots',
#   'babies food',
#   'ham',
#   'cookies',
#   'salad',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'soup', 'napkins', 'rice', 'oil', 'tea'],
#  ['zucchini',
#   'grated cheese',
#   'ketchup',
#   'oil',
#   'pokemon scarlet',
#   'milk',
#   'water spray',
#   'chicken',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'frozen smoothie',
#   'oil',
#   'ham',
#   'phone car charger',
#   'cologne',
#   'iMac',
#   'tea'],
#  ['cake', 'cream', 'corn', 'blueberries', 'burgers'],
#  ['oil', 'babies food', 'cooking oil'],
#  ['soup', 'protein bar', 'oil', 'toothpaste', 'ham', 'cooking oil', 'tea'],
#  ['candy bars',
#   'cake',
#   'whole wheat rice',
#   'oil',
#   'portal',
#   'black tea',
#   'fresh bread',
#   'ham',
#   'green beans',
#   'cooking oil'],
#  ['meatballs',
#   'cottage cheese',
#   'french fries',
#   'turkey',
#   'oil',
#   'chocolate bread',
#   'tomatoes',
#   'cologne',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cooking oil',
#   'cereals',
#   'oil',
#   'dog food',
#   'deodorant',
#   'tomatoes',
#   'yogurt cake',
#   'pet food',
#   'salmon',
#   'olive oil',
#   'fresh tuna',
#   'tea'],
#  ['oil', 'pasta', 'blueberries', 'olive oil', 'mint', 'tomato juice', 'tea'],
#  ['whole wheat rice',
#   'meatballs',
#   'frozen smoothie',
#   'oil',
#   'ketchup',
#   'gums',
#   'toothpaste',
#   'cooking oil',
#   'green grapes',
#   'tea'],
#  ['cake',
#   'napkins',
#   'phone charger',
#   'french fries',
#   'oil',
#   'ketchup',
#   'shower gel',
#   'gums',
#   'whole weat flour',
#   'muffins',
#   'pepper',
#   'burgers',
#   'bluetooth headphones',
#   'cooking oil'],
#  ['soup',
#   'napkins',
#   'oatmeal',
#   'french fries',
#   'gadget for tiktok streaming',
#   'gums',
#   'cooking oil',
#   'mushroom cream sauce',
#   'tea'],
#  ['soup',
#   'megaman zero 3',
#   'french fries',
#   'turkey',
#   'oil',
#   'ketchup',
#   'gums',
#   'milk',
#   'babies food',
#   'toilet paper',
#   'salt',
#   'tea'],
#  ['cream', 'cereals', 'rice', 'napkins'],
#  ['soup', 'oatmeal', 'oil', 'green beans', 'metroid fusion', 'tea'],
#  ['candy bars',
#   'cake',
#   'strong cheese',
#   'cereals',
#   'oil',
#   'final fantasy XXII',
#   'fresh bread',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'megaman zero 3',
#   'grated cheese',
#   'oil',
#   'fresh bread',
#   'pokemon scarlet',
#   'babies food',
#   'salmon',
#   'toilet paper',
#   'cooking oil'],
#  ['ketchup', 'yogurt cake', 'cooking oil', 'oil'],
#  ['shampoo',
#   'soup',
#   'shallot',
#   'napkins',
#   'oil',
#   'gadget for tiktok streaming',
#   'toothpaste',
#   'half-life 2',
#   'cooking oil'],
#  ['oatmeal', 'frozen vegetables', 'oil', 'sandwich', 'cooking oil'],
#  ['candy bars',
#   'napkins',
#   'rice',
#   'pokemon shield',
#   'oil',
#   'ketchup',
#   'asparagus',
#   'shower gel',
#   'milk',
#   'parmesan cheese',
#   'escalope',
#   'cooking oil',
#   'tea'],
#  ['burgers',
#   'napkins',
#   'turkey',
#   'pokemon shield',
#   'oil',
#   'dog food',
#   'shower gel',
#   'muffins',
#   'corn',
#   'ground beef',
#   'cologne',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'spaghetti',
#   'mashed potato',
#   'strong cheese',
#   'frozen vegetables',
#   'oil',
#   'avocado',
#   'gums',
#   'babies food',
#   'tomato sauce'],
#  ['candy bars',
#   'pickles',
#   'final fantasy XIX',
#   'chocolate',
#   'soda',
#   'cottage cheese',
#   'cereals',
#   'oil',
#   'honey',
#   'gums',
#   'cream',
#   'cookies',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['whole wheat pasta',
#   'napkins',
#   'oil',
#   'megaman zero 2',
#   'minecraft',
#   'toilet paper',
#   'cooking oil',
#   'tea'],
#  ['protein bar',
#   'whole wheat rice',
#   'oatmeal',
#   'hot dogs',
#   'oil',
#   'shower gel',
#   'milk',
#   'burgers',
#   'tomato sauce',
#   'cooking oil',
#   'green grapes'],
#  ['soup',
#   'cake',
#   'oatmeal',
#   'grated cheese',
#   'oil',
#   'cream',
#   'muffins',
#   'pet food',
#   'eggs',
#   'tea'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'cottage cheese',
#   'grated cheese',
#   'strong cheese',
#   'oil',
#   'portal',
#   'fresh bread',
#   'whole weat flour',
#   'parmesan cheese',
#   'eggs'],
#  ['cereals', 'whole wheat rice', 'iPad', 'tea'],
#  ['burgers',
#   'candy bars',
#   'cake',
#   'soup',
#   'mashed potato',
#   'ring light',
#   'olive oil',
#   'ketchup',
#   'gluten free bar',
#   'pet food',
#   'babies food',
#   'chili',
#   'cologne',
#   'toilet paper',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'energy bar',
#   'flax seed',
#   'sparkling water',
#   'honey',
#   'gums',
#   'muffins',
#   'babies food',
#   'melons',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'cooking oil',
#   'oil',
#   'fresh bread',
#   'gums',
#   'pasta',
#   'muffins',
#   'chicken',
#   'body spray'],
#  ['tooth brush',
#   'cotton buds',
#   'turkey',
#   'oil',
#   'mayonnaise',
#   'extra dark chocolate',
#   'toilet paper',
#   'cooking oil'],
#  ['soup',
#   'mashed potato',
#   'strong cheese',
#   'oil',
#   'deodorant',
#   'half-life 2',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'cottage cheese',
#   'french fries',
#   'ring light',
#   'vegetables mix',
#   'shrimp',
#   'milk',
#   'spinach'],
#  ['candy bars',
#   'napkins',
#   'turkey',
#   'oil',
#   'strawberries',
#   'ketchup',
#   'burger sauce',
#   'final fantasy XXII',
#   'fresh bread',
#   'pet food',
#   'escalope',
#   'ratchet & clank 3',
#   'tea'],
#  ['meatballs', 'beer', 'oil', 'olive oil', 'zucchini'],
#  ['soup',
#   'tooth brush',
#   'napkins',
#   'french fries',
#   'turkey',
#   'oil',
#   'pokemon shield',
#   'strawberries',
#   'asparagus',
#   'mayonnaise',
#   'gums',
#   'pasta',
#   'escalope',
#   'eggs',
#   'burgers',
#   'mint',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'rice',
#   'strong cheese',
#   'pokemon violet',
#   'oil',
#   'milk',
#   'escalope',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'whole wheat rice',
#   'oil',
#   'flax seed',
#   'ratchet & clank',
#   'milk',
#   'cream',
#   'gums',
#   'pet food',
#   'mayonnaise',
#   'yogurt cake',
#   'tea'],
#  ['candy bars', 'cake', 'oatmeal', 'hot dogs', 'french fries', 'butter'],
#  ['cake',
#   'phone charger',
#   'strong cheese',
#   'oil',
#   'asparagus',
#   'gums',
#   'muffins',
#   'ham',
#   'green grapes'],
#  ['cake', 'french fries', 'oil', 'muffins', 'sandwich', 'cooking oil', 'tea'],
#  ['whole weat flour', 'muffins', 'corn', 'butter'],
#  ['tooth brush',
#   'shallot',
#   'mashed potato',
#   'cottage cheese',
#   'french fries',
#   'strong cheese',
#   'oil',
#   'gums',
#   'yogurt cake',
#   'megaman zero'],
#  ['cake',
#   'cologne',
#   'grated cheese',
#   'gums',
#   'metroid prime',
#   'sandwich',
#   'light mayo',
#   'cooking oil',
#   'tea'],
#  ['pickles',
#   'cottage cheese',
#   'french fries',
#   'oil',
#   'ketchup',
#   'gums',
#   'sandwich',
#   'burgers',
#   'tea'],
#  ['yams',
#   'strong cheese',
#   'cereals',
#   'oil',
#   'tomatoes',
#   'cologne',
#   'body spray',
#   'butter',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['cottage cheese',
#   'oil',
#   'catfish',
#   'megaman zero 4',
#   'barbecue sauce',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'oatmeal',
#   'megaman zero 3',
#   'oil',
#   'parmesan cheese',
#   'muffins',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['pickles',
#   'soup',
#   'cake',
#   'french fries',
#   'oil',
#   'deodorant',
#   'shower gel',
#   'muffins',
#   'sandwich',
#   'cat food',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['yams',
#   'cake',
#   'napkins',
#   'rice',
#   'french fries',
#   'fromage blanc',
#   'gums',
#   'mayonnaise',
#   'pet food',
#   'salad',
#   'cooking oil'],
#  ['cake',
#   'spaghetti',
#   'rice',
#   'muffins',
#   'babies food',
#   'yogurt cake',
#   'body spray',
#   'tomato sauce',
#   'cooking oil'],
#  ['soup',
#   'meatballs',
#   'spaghetti',
#   'rice',
#   'oatmeal',
#   'oil',
#   'toothpaste',
#   'milk',
#   'muffins',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'eggplant',
#   'french fries',
#   'cereals',
#   'oil',
#   'frozen smoothie',
#   'asparagus',
#   'pokemon scarlet',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'whole wheat pasta',
#   'oil',
#   'fresh bread',
#   'whole weat flour',
#   'carrots',
#   'light mayo',
#   'tomato juice',
#   'tomato sauce'],
#  ['ketchup', 'oil', 'pasta', 'muffins', 'green beans', 'tea'],
#  ['napkins',
#   'eggplant',
#   'oil',
#   'fresh bread',
#   'parmesan cheese',
#   'muffins',
#   'salmon',
#   'tea'],
#  ['cake',
#   'french fries',
#   'fresh bread',
#   'sandwich',
#   'toilet paper',
#   'butter',
#   'tea'],
#  ['bramble',
#   'soup',
#   'cake',
#   'napkins',
#   'oil',
#   'gadget for tiktok streaming',
#   'fresh bread',
#   'tomatoes',
#   'canned_tuna',
#   'blueberries',
#   'mint',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'spaghetti',
#   'french fries',
#   'oil',
#   'fresh bread',
#   'gums',
#   'pet food',
#   'half-life: alyx',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'meatballs',
#   'ring light',
#   'oil',
#   'pancakes',
#   'nonfat milk',
#   'chili',
#   'cookies',
#   'protein bar'],
#  ['candy bars', 'napkins', 'sparkling water', 'muffins', 'cooking oil'],
#  ['burgers',
#   'cake',
#   'cereals',
#   'oil',
#   'cookies',
#   'body spray',
#   'salad',
#   'barbecue sauce',
#   'cooking oil'],
#  ['candy bars',
#   'cake',
#   'french fries',
#   'mineral water',
#   'oil',
#   'asparagus',
#   'low fat yogurt',
#   'fresh bread',
#   'shrimp',
#   'gums',
#   'cream',
#   'pet food',
#   'portal 2',
#   'cooking oil',
#   'metroid fusion'],
#  ['cake', 'whole wheat rice', 'muffins', 'cooking oil', 'tea'],
#  ['soup',
#   'cake',
#   'oatmeal',
#   'grated cheese',
#   'french fries',
#   'half-life 2',
#   'eggs',
#   'tea'],
#  ['soup',
#   'cake',
#   'oatmeal',
#   'oil',
#   'deodorant',
#   'low fat yogurt',
#   'muffins',
#   'pet food',
#   'almonds',
#   'cologne',
#   'megaman zero',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'oil',
#   'airpods',
#   'black tea',
#   'final fantasy XXII',
#   'babies food',
#   'white wine',
#   'burgers',
#   'salt',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['yams', 'oil', 'pasta', 'cooking oil', 'green grapes'],
#  ['cotton buds',
#   'napkins',
#   'zucchini',
#   'strong cheese',
#   'oil',
#   'strawberries',
#   'parmesan cheese',
#   'muffins',
#   'whole weat flour',
#   'phone car charger',
#   'olive oil',
#   'salad',
#   'body spray',
#   'vacuum cleaner',
#   'tea'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'strong cheese',
#   'mineral water',
#   'oil',
#   'pokemon sword',
#   'mayonnaise',
#   'tea'],
#  ['frozen smoothie',
#   'oil',
#   'fromage blanc',
#   'burger sauce',
#   'vegetables mix',
#   'fresh bread',
#   'cookies',
#   'butter'],
#  ['candy bars',
#   'soup',
#   'napkins',
#   'french fries',
#   'oil',
#   'shower gel',
#   'gums',
#   'melons',
#   'yogurt cake',
#   'blueberries',
#   'eggs',
#   'olive oil'],
#  ['cider',
#   'soup',
#   'dessert wine',
#   'cake',
#   'soda',
#   'shampoo',
#   'oil',
#   'flax seed',
#   'toothpaste',
#   'whole weat flour',
#   'cream',
#   'final fantasy XX',
#   'chicken',
#   'metroid fusion',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'rice',
#   'ratchet & clank',
#   'gums',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'meatballs',
#   'turkey',
#   'oil',
#   'bacon',
#   'pokemon scarlet',
#   'gums',
#   'cookies',
#   'tomato juice',
#   'barbecue sauce',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'spaghetti',
#   'strong cheese',
#   'oil',
#   'green beans',
#   'asparagus',
#   'gums',
#   'whole weat flour',
#   'muffins',
#   'cookies',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['yams',
#   'shower gel',
#   'vegetables mix',
#   'salmon',
#   'mushroom cream sauce',
#   'tea'],
#  ['tooth brush', 'whole wheat rice', 'oil', 'fresh bread', 'gums', 'tea'],
#  ['soup', 'cake', 'soda', 'oil', 'airpods', 'half-life 2', 'portal 2'],
#  ['soup', 'oil', 'cereals', 'tea'],
#  ['candy bars',
#   'cake',
#   'airpods',
#   'ketchup',
#   'oil',
#   'light mayo',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'shower gel', 'tea'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'zucchini',
#   'rice',
#   'french fries',
#   'strong cheese',
#   'ketchup',
#   'laptop',
#   'fresh bread',
#   'toothpaste',
#   'pet food',
#   'cookies',
#   'megaman zero 4',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'shallot',
#   'spaghetti',
#   'frozen smoothie',
#   'oil',
#   'strawberries',
#   'ketchup',
#   'final fantasy XXII',
#   'shrimp',
#   'cologne',
#   'cooking oil'],
#  ['candy bars',
#   'bramble',
#   'mineral water',
#   'shower gel',
#   'toothpaste',
#   'cream',
#   'extra dark chocolate',
#   'eggs',
#   'cooking oil'],
#  ['soda',
#   'chutney',
#   'oatmeal',
#   'strong cheese',
#   'french fries',
#   'oil',
#   'strawberries',
#   'shower gel',
#   'final fantasy XXII',
#   'gums',
#   'whole weat flour',
#   'almonds',
#   'blueberries',
#   'spinach',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'bacon', 'oil', 'gums', 'yogurt cake', 'cooking oil'],
#  ['candy bars', 'grated cheese', 'fromage blanc', 'gums', 'green tea'],
#  ['energy bar',
#   'mineral water',
#   'seabass',
#   'oil',
#   'melons',
#   'cookies',
#   'metroid fusion'],
#  ['soda', 'oil', 'fresh bread', 'gums', 'cologne', 'cooking oil'],
#  ['fresh bread', 'gums', 'pokemon scarlet', 'tea'],
#  ['oil',
#   'ketchup',
#   'airpods',
#   'sparkling water',
#   'gums',
#   'cream',
#   'yogurt cake',
#   'body spray',
#   'cooking oil'],
#  ['candy bars',
#   'cologne',
#   'laptop',
#   'oil',
#   'low fat yogurt',
#   'fresh bread',
#   'gums',
#   'mayonnaise',
#   'white wine',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'napkins',
#   'strong cheese',
#   'french fries',
#   'oil',
#   'avocado',
#   'gums',
#   'tomatoes',
#   'mayonnaise',
#   'metroid fusion',
#   'cookies',
#   'cooking oil',
#   'mushroom cream sauce',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'cologne',
#   'gums',
#   'muffins',
#   'yogurt cake',
#   'ratchet & clank 3',
#   'burgers',
#   'megaman zero 4',
#   'cooking oil'],
#  ['french fries',
#   'oil',
#   'fresh bread',
#   'muffins',
#   'yogurt cake',
#   'white wine',
#   'cologne',
#   'megaman zero 4',
#   'butter',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'oil',
#   'ratchet & clank',
#   'gums',
#   'escalope',
#   'half-life: alyx',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['cereals',
#   'ketchup',
#   'low fat yogurt',
#   'parmesan cheese',
#   'pet food',
#   'sandwich',
#   'cookies',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'tooth brush',
#   'oatmeal',
#   'turkey',
#   'fresh bread',
#   'toothpaste',
#   'milk',
#   'muffins',
#   'sandwich',
#   'toilet paper',
#   'salad',
#   'cooking oil'],
#  ['soup',
#   'oatmeal',
#   'oil',
#   'pasta',
#   'cookies',
#   'megaman zero 4',
#   'red wine',
#   'cooking oil',
#   'tea'],
#  ['chocolate', 'cream', 'trout', 'iMac', 'zucchini'],
#  ['cake', 'oil', 'portal', 'yogurt cake', 'pet food'],
#  ['soup',
#   'cake',
#   'napkins',
#   'spaghetti',
#   'strong cheese',
#   'french fries',
#   'gadget for tiktok streaming',
#   'cereals',
#   'final fantasy XXII',
#   'extra dark chocolate',
#   'olive oil',
#   'mint',
#   'tea'],
#  ['fresh bread', 'napkins', 'tomato sauce', 'tea'],
#  ['candy bars',
#   'soda',
#   'bramble',
#   'cottage cheese',
#   'turkey',
#   'oil',
#   'gadget for tiktok streaming',
#   'milk',
#   'muffins',
#   'pet food',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'cake', 'laptop', 'frozen smoothie', 'fresh bread', 'milk'],
#  ['candy bars', 'oil', 'gluten free bar', 'cooking oil', 'cauliflower', 'tea'],
#  ['soup', 'napkins', 'oil', 'muffins', 'pasta', 'olive oil', 'barbecue sauce'],
#  ['oatmeal',
#   'oil',
#   'shower gel',
#   'pokemon scarlet',
#   'milk',
#   'hand protein bar',
#   'escalope',
#   'barbecue sauce',
#   'chocolate bread'],
#  ['candy bars',
#   'cake',
#   'oil',
#   'shower gel',
#   'cream',
#   'pasta',
#   'green beans',
#   'iMac',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'oil',
#   'fromage blanc',
#   'fresh bread',
#   'minecraft',
#   'babies food',
#   'cooking oil'],
#  ['final fantasy XIX',
#   'soda',
#   'cake',
#   'mashed potato',
#   'oil',
#   'bacon',
#   'flax seed',
#   'cream',
#   'babies food',
#   'pet food',
#   'chili',
#   'olive oil',
#   'tea'],
#  ['cake',
#   'spaghetti',
#   'mashed potato',
#   'oil',
#   'milk',
#   'burgers',
#   'toilet paper',
#   'cat food'],
#  ['soup',
#   'oatmeal',
#   'iPad',
#   'cottage cheese',
#   'oil',
#   'toothpaste',
#   'cream',
#   'gums',
#   'olive oil',
#   'red wine',
#   'tea'],
#  ['final fantasy XIX', 'cotton buds', 'napkins', 'chutney', 'tea'],
#  ['shampoo',
#   'final fantasy XIX',
#   'yams',
#   'oatmeal',
#   'french fries',
#   'oil',
#   'flax seed',
#   'mayonnaise',
#   'red wine',
#   'herb & pepper'],
#  ['energy bar',
#   'oil',
#   'airpods',
#   'strawberries',
#   'gums',
#   'energy drink',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['final fantasy XIX',
#   'shallot',
#   'mashed potato',
#   'frozen vegetables',
#   'oil',
#   'water spray',
#   'iMac'],
#  ['oatmeal',
#   'rice',
#   'ring light',
#   'cereals',
#   'oil',
#   'asparagus',
#   'shower gel',
#   'ratchet & clank',
#   'metroid prime',
#   'final fantasy XX',
#   'body spray',
#   'cooking oil',
#   'tea'],
#  ['cider',
#   'soup',
#   'barbecue sauce',
#   'ketchup',
#   'avocado',
#   'shower gel',
#   'gums',
#   'salad',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'whole wheat rice',
#   'napkins',
#   'grated cheese',
#   'oil',
#   'fromage blanc',
#   'white wine',
#   'eggs',
#   'cooking oil'],
#  ['oil',
#   'fromage blanc',
#   'fresh bread',
#   'toothpaste',
#   'pancakes',
#   'pasta',
#   'final fantasy XX',
#   'half-life: alyx',
#   'tea'],
#  ['dessert wine',
#   'cake',
#   'napkins',
#   'oil',
#   'extra dark chocolate',
#   'cooking oil',
#   'tea'],
#  ['oil',
#   'ketchup',
#   'gums',
#   'parmesan cheese',
#   'hand protein bar',
#   'olive oil',
#   'tomato sauce'],
#  ['soup', 'cake', 'napkins', 'oil', 'sparkling water', 'olive oil', 'tea'],
#  ['yams',
#   'black beer',
#   'cake',
#   'french fries',
#   'dog food',
#   'milk',
#   'muffins',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cottage cheese',
#   'mineral water',
#   'oil',
#   'frozen vegetables',
#   'final fantasy XXII',
#   'ratchet & clank',
#   'gums',
#   'tomatoes',
#   'yogurt cake',
#   'cooking oil',
#   'tea'],
#  ['napkins',
#   'oil',
#   'fromage blanc',
#   'asparagus',
#   'vegetables mix',
#   'gums',
#   'muffins',
#   'pasta',
#   'half-life 2',
#   'cooking oil',
#   'tea'],
#  ['light cream',
#   'napkins',
#   'french fries',
#   'muffins',
#   'cookies',
#   'body spray',
#   'cooking oil'],
#  ['yams', 'oil', 'white wine', 'water spray', 'green grapes'],
#  ['cake',
#   'napkins',
#   'cotton buds',
#   'french fries',
#   'frozen vegetables',
#   'oil',
#   'catfish',
#   'fresh bread',
#   'ratchet & clank',
#   'pet food',
#   'yogurt cake',
#   'phone car charger',
#   'cooking oil',
#   'tea'],
#  ['gluten free bar',
#   'shower gel',
#   'ratchet & clank',
#   'parmesan cheese',
#   'babies food',
#   'white wine',
#   'cooking oil',
#   'tea'],
#  ['iphone 10',
#   'hot dogs',
#   'pokemon shield',
#   'toothpaste',
#   'carrots',
#   'muffins',
#   'tomatoes',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['black beer',
#   'tooth brush',
#   'whole wheat pasta',
#   'whole wheat rice',
#   'samsung galaxy 10',
#   'strong cheese',
#   'oil',
#   'flax seed',
#   'burger sauce',
#   'fresh bread',
#   'gums',
#   'herb & pepper',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'whole wheat pasta',
#   'oatmeal',
#   'barbecue sauce',
#   'asparagus',
#   'herb & pepper',
#   'cooking oil',
#   'cauliflower'],
#  ['cake', 'cottage cheese', 'oil', 'cream', 'mint green tea', 'tea'],
#  ['oil', 'flax seed', 'fresh bread', 'cream', 'cooking oil'],
#  ['shampoo',
#   'bramble',
#   'napkins',
#   'mint green tea',
#   'strong cheese',
#   'oil',
#   'bacon',
#   'deodorant',
#   'fresh bread',
#   'gums',
#   'muffins',
#   'olive oil',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'napkins',
#   'spaghetti',
#   'oil',
#   'milk',
#   'muffins',
#   'almonds',
#   'olive oil',
#   'tea'],
#  ['candy bars',
#   'dessert wine',
#   'rice',
#   'french fries',
#   'minecraft',
#   'olive oil',
#   'tea'],
#  ['soda', 'grated cheese', 'oil', 'mayonnaise', 'yogurt cake'],
#  ['cake',
#   'megaman zero 3',
#   'dog food',
#   'sparkling water',
#   'final fantasy XXII',
#   'fresh tuna',
#   'chocolate bread'],
#  ['soup',
#   'spaghetti',
#   'phone charger',
#   'french fries',
#   'oil',
#   'seabass',
#   'babies food',
#   'corn',
#   'half-life: alyx',
#   'green beans',
#   'cooking oil',
#   'tea'],
#  ['bramble',
#   'oil',
#   'tomatoes',
#   'muffins',
#   'babies food',
#   'parmesan cheese',
#   'tea'],
#  ['pickles', 'oil', 'ham', 'cooking oil'],
#  ['oatmeal',
#   'cotton buds',
#   'oil',
#   'ketchup',
#   'ratchet & clank',
#   'gums',
#   'tomatoes',
#   'babies food',
#   'ratchet & clank 3',
#   'body spray',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'oatmeal',
#   'light cream',
#   'oil',
#   'airpods',
#   'fresh bread',
#   'gums',
#   'pasta',
#   'babies food',
#   'melons',
#   'cookies',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'meatballs',
#   'antioxydant juice',
#   'spaghetti',
#   'french fries',
#   'oil',
#   'flax seed',
#   'gums',
#   'pet food',
#   'yogurt cake',
#   'escalope',
#   'olive oil',
#   'salad',
#   'french wine'],
#  ['soup', 'rice', 'oil', 'asparagus', 'herb & pepper', 'cooking oil'],
#  ['cake', 'oil', 'asparagus', 'pasta', 'butter'],
#  ['dessert wine', 'oil', 'deodorant', 'pet food', 'cooking oil'],
#  ['final fantasy XIX',
#   'light cream',
#   'ketchup',
#   'pokemon scarlet',
#   'cooking oil'],
#  ['soup',
#   'tooth brush',
#   'cottage cheese',
#   'oil',
#   'fromage blanc',
#   'airpods',
#   'melons',
#   'pet food',
#   'pepper',
#   'tomato sauce'],
#  ['candy bars', 'ring light', 'oil', 'muffins', 'green beans', 'tea'],
#  ['candy bars',
#   'cider',
#   'iPad',
#   'oil',
#   'mayonnaise',
#   'trout',
#   'yogurt cake',
#   'spinach',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'yams',
#   'cake',
#   'spaghetti',
#   'oil',
#   'bacon',
#   'gadget for tiktok streaming',
#   'low fat yogurt',
#   'fresh bread',
#   'muffins',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['yams', 'cake', 'gums', 'body spray', 'bluetooth headphones', 'cooking oil'],
#  ['soup',
#   'cake',
#   'napkins',
#   'oil',
#   'final fantasy XXII',
#   'muffins',
#   'ratchet & clank 2',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'hot dogs',
#   'french fries',
#   'oil',
#   'ketchup',
#   'seabass',
#   'fresh bread',
#   'metroid prime',
#   'eggs',
#   'toilet paper',
#   'bluetooth headphones'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'oil',
#   'black tea',
#   'gums',
#   'parmesan cheese',
#   'cooking oil'],
#  ['tooth brush',
#   'cake',
#   'napkins',
#   'oil',
#   'fresh bread',
#   'yogurt cake',
#   'extra dark chocolate',
#   'half-life 2',
#   'burgers',
#   'salt',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cereals',
#   'oil',
#   'airpods',
#   'whole weat flour',
#   'energy drink',
#   'ham',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['soup',
#   'dessert wine',
#   'french fries',
#   'cereals',
#   'oil',
#   'deodorant',
#   'sparkling water',
#   'cream',
#   'gums',
#   'nonfat milk',
#   'babies food',
#   'body spray',
#   'cat food'],
#  ['candy bars',
#   'oatmeal',
#   'spaghetti',
#   'mashed potato',
#   'oil',
#   'fresh bread',
#   'milk',
#   'gums',
#   'whole weat flour',
#   'final fantasy XX',
#   'mint',
#   'cooking oil'],
#  ['cake',
#   'whole wheat pasta',
#   'oil',
#   'muffins',
#   'metroid prime',
#   'toilet paper',
#   'tea'],
#  ['yams', 'french fries', 'oil', 'honey', 'toothpaste', 'cooking oil', 'tea'],
#  ['black beer',
#   'soup',
#   'cake',
#   'napkins',
#   'spaghetti',
#   'phone charger',
#   'ring light',
#   'ketchup',
#   'oil',
#   'gums',
#   'almonds',
#   'ham',
#   'cologne',
#   'cooking oil'],
#  ['cake',
#   'mint green tea',
#   'mineral water',
#   'oil',
#   'body spray',
#   'tomato sauce',
#   'toilet paper',
#   'tea'],
#  ['cake', 'oil', 'milk', 'brownies', 'burgers', 'iMac', 'tomato sauce', 'tea'],
#  ['candy bars', 'cottage cheese', 'french fries', 'oil', 'muffins', 'tea'],
#  ['cake',
#   'napkins',
#   'oil',
#   'fresh bread',
#   'mayonnaise',
#   'babies food',
#   'yogurt cake',
#   'cooking oil'],
#  ['candy bars',
#   'napkins',
#   'phone charger',
#   'oil',
#   'asparagus',
#   'vegetables mix',
#   'gums',
#   'muffins',
#   'salad',
#   'tomato sauce',
#   'cooking oil',
#   'metroid fusion'],
#  ['candy bars',
#   'flax seed',
#   'muffins',
#   'babies food',
#   'half-life: alyx',
#   'sandwich',
#   'body spray',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'spaghetti',
#   'energy bar',
#   'strong cheese',
#   'french fries',
#   'oil',
#   'fromage blanc',
#   'final fantasy XXII',
#   'gums',
#   'whole weat flour',
#   'ratchet & clank 2',
#   'yogurt cake',
#   'milk',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['oil',
#   'fresh bread',
#   'gums',
#   'toothpaste',
#   'cream',
#   'green tea',
#   'metroid prime',
#   'salmon',
#   'mint',
#   'herb & pepper',
#   'protein bar'],
#  ['candy bars',
#   'cake',
#   'cooking oil',
#   'oil',
#   'sparkling water',
#   'cream',
#   'muffins',
#   'babies food',
#   'zucchini',
#   'tea'],
#  ['cake',
#   'napkins',
#   'light cream',
#   'megaman zero 3',
#   'oil',
#   'asparagus',
#   'almonds',
#   'yogurt cake',
#   'muffins',
#   'salad',
#   'cooking oil',
#   'tea'],
#  ['cake', 'napkins', 'whole wheat pasta', 'light cream', 'oil', 'olive oil'],
#  ['cake',
#   'oatmeal',
#   'mashed potato',
#   'pokemon shield',
#   'shrimp',
#   'pasta',
#   'cologne',
#   'chicken',
#   'tea'],
#  ['shampoo',
#   'cake',
#   'megaman zero 3',
#   'frozen vegetables',
#   'oil',
#   'fresh bread',
#   'mayonnaise',
#   'pancakes',
#   'muffins',
#   'escalope',
#   'cooking oil',
#   'tea'],
#  ['chocolate',
#   'napkins',
#   'cereals',
#   'black tea',
#   'pokemon sword',
#   'cologne',
#   'olive oil',
#   'tea'],
#  ['napkins',
#   'razor',
#   'strong cheese',
#   'oil',
#   'gums',
#   'tomatoes',
#   'pasta',
#   'babies food',
#   'pet food',
#   'cookies',
#   'cooking oil'],
#  ['candy bars', 'cake', 'oil', 'sandwich', 'ground beef', 'chicken', 'tea'],
#  ['candy bars', 'cake', 'cooking oil', 'ketchup'],
#  ['cake',
#   'french fries',
#   'oil',
#   'airpods',
#   'catfish',
#   'ratchet & clank',
#   'gums',
#   'tomatoes',
#   'carrots',
#   'spinach',
#   'cooking oil'],
#  ['bramble', 'oatmeal', 'cooking oil'],
#  ['candy bars',
#   'french fries',
#   'frozen vegetables',
#   'oil',
#   'ketchup',
#   'gums',
#   'pasta',
#   'sandwich',
#   'cologne',
#   'salad',
#   'tomato sauce',
#   'tea'],
#  ['candy bars',
#   'shallot',
#   'oil',
#   'gums',
#   'yogurt cake',
#   'metroid prime',
#   'phone car charger'],
#  ['napkins',
#   'spaghetti',
#   'gluten free bar',
#   'sparkling water',
#   'trout',
#   'nonfat milk',
#   'portal 2',
#   'toilet paper',
#   'tomato juice',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'oil', 'gums', 'ground beef', 'cookies'],
#  ['soda',
#   'cake',
#   'napkins',
#   'cotton buds',
#   'mashed potato',
#   'cooking oil',
#   'oil',
#   'pokemon sword',
#   'cream',
#   'gums',
#   'yogurt cake',
#   'zucchini'],
#  ['soup',
#   'napkins',
#   'hot dogs',
#   'oil',
#   'gums',
#   'muffins',
#   'yogurt cake',
#   'tea'],
#  ['fresh bread', 'soup', 'cotton buds', 'tea'],
#  ['shampoo',
#   'vacuum cleaner',
#   'napkins',
#   'oil',
#   'flax seed',
#   'pasta',
#   'burgers',
#   'light mayo',
#   'cooking oil',
#   'metroid fusion',
#   'tea'],
#  ['cake',
#   'iPad',
#   'spaghetti',
#   'mashed potato',
#   'cereals',
#   'ketchup',
#   'oil',
#   'honey',
#   'milk',
#   'pasta',
#   'cookies',
#   'megaman zero',
#   'cooking oil',
#   'tea'],
#  ['napkins',
#   'cottage cheese',
#   'oil',
#   'asparagus',
#   'muffins',
#   'melons',
#   'white wine',
#   'pasta',
#   'cooking oil',
#   'tea'],
#  ['shampoo',
#   'napkins',
#   'oil',
#   'low fat yogurt',
#   'cream',
#   'parmesan cheese',
#   'minecraft',
#   'pet food',
#   'herb & pepper',
#   'tea'],
#  ['soda',
#   'spaghetti',
#   'french fries',
#   'pokemon shield',
#   'champagne',
#   'yogurt cake',
#   'ratchet & clank 3'],
#  ['candy bars',
#   'chocolate',
#   'napkins',
#   'oil',
#   'bacon',
#   'toothpaste',
#   'cream',
#   'babies food',
#   'sandwich',
#   'burgers',
#   'mint green tea',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'turkey',
#   'oil',
#   'megaman zero 2',
#   'gums',
#   'tomatoes',
#   'milk',
#   'olive oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'oatmeal',
#   'phone charger',
#   'oil',
#   'melons',
#   'green beans',
#   'cooking oil',
#   'tea'],
#  ['oatmeal', 'hot dogs', 'oil', 'melons', 'barbecue sauce', 'tea'],
#  ['candy bars',
#   'shallot',
#   'eggplant',
#   'spaghetti',
#   'barbecue sauce',
#   'oil',
#   'almonds',
#   'yogurt cake',
#   'olive oil',
#   'butter',
#   'cat food',
#   'cooking oil'],
#  ['ketchup', 'oil'],
#  ['cider',
#   'soup',
#   'hot dogs',
#   'cottage cheese',
#   'oil',
#   'avocado',
#   'gums',
#   'pet food',
#   'ham',
#   'salmon',
#   'barbecue sauce'],
#  ['soup',
#   'oil',
#   'gums',
#   'muffins',
#   'extra dark chocolate',
#   'iMac',
#   'chicken',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'pokemon shield',
#   'cereals',
#   'gums',
#   'pancakes',
#   'ratchet & clank 2',
#   'babies food',
#   'pet food',
#   'cookies',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['dessert wine',
#   'cottage cheese',
#   'oil',
#   'gums',
#   'pepper',
#   'salt',
#   'herb & pepper',
#   'cooking oil',
#   'tea'],
#  ['oil', 'pepper', 'final fantasy XXII'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'oil',
#   'ketchup',
#   'parmesan cheese',
#   'babies food',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'shampoo', 'napkins', 'cream', 'gums', 'cooking oil', 'tea'],
#  ['candy bars',
#   'french fries',
#   'pokemon violet',
#   'oil',
#   'laptop',
#   'gluten free bar',
#   'megaman zero 4',
#   'vegetables mix',
#   'fresh bread',
#   'yogurt cake',
#   'water spray',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'napkins',
#   'rice',
#   'oil',
#   'portal 2',
#   'ground beef',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'whole wheat rice',
#   'butter',
#   'oil',
#   'fresh bread',
#   'milk',
#   'ground beef',
#   'pepper',
#   'megaman zero 2',
#   'red wine',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'shampoo',
#   'cake',
#   'oil',
#   'fromage blanc',
#   'chocolate bread',
#   'gums',
#   'whole weat flour',
#   'cooking oil',
#   'metroid fusion',
#   'tea'],
#  ['napkins',
#   'french fries',
#   'oil',
#   'fresh bread',
#   'muffins',
#   'pet food',
#   'half-life 2',
#   'pasta',
#   'chutney'],
#  ['cake',
#   'phone charger',
#   'french fries',
#   'oil',
#   'deodorant',
#   'sparkling water',
#   'pasta',
#   'cookies',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['oil', 'yogurt cake', 'deodorant', 'eggs'],
#  ['cotton buds',
#   'megaman zero 3',
#   'seabass',
#   'brownies',
#   'portal 2',
#   'cooking oil'],
#  ['cottage cheese',
#   'oil',
#   'ketchup',
#   'milk',
#   'carrots',
#   'muffins',
#   'babies food',
#   'toothpaste',
#   'mayonnaise',
#   'water spray',
#   'cooking oil',
#   'green grapes',
#   'tea'],
#  ['soup', 'soda', 'pokemon violet', 'milk', 'escalope', 'salmon'],
#  ['cider',
#   'whole wheat rice',
#   'ring light',
#   'ketchup',
#   'gums',
#   'muffins',
#   'salmon',
#   'chili',
#   'body spray',
#   'tea'],
#  ['frozen vegetables',
#   'oil',
#   'honey',
#   'melons',
#   'yogurt cake',
#   'toilet paper',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'oil',
#   'final fantasy XXII',
#   'energy drink',
#   'almonds',
#   'corn',
#   'cooking oil',
#   'tea'],
#  ['final fantasy XIX',
#   'cake',
#   'oil',
#   'gums',
#   'green beans',
#   'megaman zero',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'mint green tea',
#   'oil',
#   'french wine',
#   'whole weat flour',
#   'muffins',
#   'yogurt cake',
#   'olive oil',
#   'cooking oil',
#   'vacuum cleaner',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'meatballs',
#   'whole wheat rice',
#   'oatmeal',
#   'mineral water',
#   'oil',
#   'asparagus',
#   'pancakes',
#   'megaman zero 4',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'frozen vegetables',
#   'oil',
#   'toothpaste',
#   'muffins',
#   'cooking oil',
#   'green grapes',
#   'tea'],
#  ['cake', 'napkins', 'bacon', 'gums', 'pet food', 'cooking oil'],
#  ['candy bars', 'soup', 'cake', 'napkins', 'ketchup', 'oil', 'cooking oil'],
#  ['napkins', 'eggplant', 'french fries', 'ring light', 'oil', 'bacon'],
#  ['cake',
#   'grated cheese',
#   'frozen vegetables',
#   'oil',
#   'ketchup',
#   'muffins',
#   'chili',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['light cream',
#   'whole wheat rice',
#   'chicken',
#   'oil',
#   'portal',
#   'shower gel',
#   'honey',
#   'fresh bread',
#   'tomatoes',
#   'pet food',
#   'spinach',
#   'body spray',
#   'cooking oil',
#   'tea'],
#  ['napkins',
#   'oil',
#   'milk',
#   'muffins',
#   'pet food',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'turkey',
#   'pokemon shield',
#   'oil',
#   'ketchup',
#   'asparagus',
#   'fresh bread',
#   'gums',
#   'whole weat flour',
#   'pet food',
#   'tomato sauce',
#   'tea'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'soup',
#   'chicken',
#   'oil',
#   'cream',
#   'yogurt cake',
#   'phone car charger',
#   'olive oil',
#   'toilet paper',
#   'cooking oil'],
#  ['cake', 'pokemon shield', 'oil', 'gums', 'babies food', 'escalope'],
#  ['cake',
#   'napkins',
#   'oatmeal',
#   'oil',
#   'tomatoes',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['oil', 'muffins'],
#  ['soda',
#   'cake',
#   'tooth brush',
#   'eggplant',
#   'oil',
#   'bacon',
#   'final fantasy XXII',
#   'pasta',
#   'toilet paper',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['soup',
#   'protein bar',
#   'napkins',
#   'grated cheese',
#   'oil',
#   'strawberries',
#   'deodorant',
#   'asparagus',
#   'gluten free bar',
#   'fromage blanc',
#   'ketchup',
#   'gums',
#   'muffins',
#   'yogurt cake',
#   'ratchet & clank 2',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'chocolate',
#   'cake',
#   'napkins',
#   'spaghetti',
#   'rice',
#   'cottage cheese',
#   'oil',
#   'low fat yogurt',
#   'fresh bread',
#   'babies food',
#   'light mayo',
#   'chicken',
#   'tea'],
#  ['shallot',
#   'black tea',
#   'pokemon scarlet',
#   'vacuum cleaner',
#   'cooking oil',
#   'green grapes'],
#  ['napkins',
#   'strong cheese',
#   'oil',
#   'fromage blanc',
#   'gums',
#   'parmesan cheese',
#   'metroid prime',
#   'cookies',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'whole wheat rice',
#   'ring light',
#   'fresh bread',
#   'cream',
#   'milk',
#   'mint green tea'],
#  ['napkins',
#   'hot dogs',
#   'rice',
#   'oil',
#   'avocado',
#   'ketchup',
#   'asparagus',
#   'flax seed',
#   'tomatoes',
#   'tea'],
#  ['candy bars', 'mayonnaise', 'portal', 'tea'],
#  ['candy bars',
#   'shampoo',
#   'cake',
#   'laptop',
#   'airpods',
#   'green beans',
#   'milk',
#   'parmesan cheese',
#   'muffins',
#   'pet food',
#   'ground beef',
#   'eggs',
#   'salmon',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'cereals',
#   'oil',
#   'gums',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'oatmeal',
#   'mashed potato',
#   'mint green tea',
#   'turkey',
#   'oil',
#   'toothpaste',
#   'green tea',
#   'ground beef',
#   'vacuum cleaner',
#   'cooking oil'],
#  ['oatmeal',
#   'corn',
#   'cookies',
#   'bluetooth headphones',
#   'cooking oil',
#   'metroid fusion'],
#  ['oil',
#   'avocado',
#   'fresh bread',
#   'white wine',
#   'phone car charger',
#   'chutney',
#   'tea'],
#  ['eggplant',
#   'ketchup',
#   'oil',
#   'deodorant',
#   'gums',
#   'pancakes',
#   'almonds',
#   'pet food',
#   'butter',
#   'cooking oil'],
#  ['candy bars',
#   'napkins',
#   'airpods',
#   'oil',
#   'fresh bread',
#   'yogurt cake',
#   'escalope',
#   'pepper',
#   'megaman zero',
#   'butter',
#   'herb & pepper',
#   'cooking oil'],
#  ['candy bars',
#   'napkins',
#   'meatballs',
#   'razor',
#   'french fries',
#   'mineral water',
#   'oil',
#   'fromage blanc',
#   'iMac',
#   'cooking oil',
#   'tea'],
#  ['mint green tea',
#   'oil',
#   'gums',
#   'escalope',
#   'half-life 2',
#   'extra dark chocolate',
#   'olive oil'],
#  ['candy bars',
#   'soup',
#   'napkins',
#   'rice',
#   'pokemon shield',
#   'oil',
#   'shower gel',
#   'low fat yogurt',
#   'melons',
#   'herb & pepper'],
#  ['shampoo',
#   'candy bars',
#   'cake',
#   'spaghetti',
#   'oil',
#   'portal',
#   'fresh bread',
#   'milk',
#   'babies food',
#   'cologne',
#   'light mayo',
#   'cooking oil',
#   'mushroom cream sauce',
#   'tea'],
#  ['oil', 'dog food', 'muffins', 'babies food', 'chutney', 'cooking oil'],
#  ['candy bars',
#   'final fantasy XIX',
#   'hot dogs',
#   'turkey',
#   'cereals',
#   'oil',
#   'strawberries',
#   'minecraft',
#   'olive oil',
#   'butter',
#   'ratchet & clank 2',
#   'tea'],
#  ['meatballs',
#   'eggplant',
#   'catfish',
#   'ratchet & clank 3',
#   'body spray',
#   'cooking oil',
#   'metroid fusion',
#   'tea'],
#  ['yams',
#   'oil',
#   'fresh bread',
#   'phone car charger',
#   'chicken',
#   'cooking oil',
#   'tea'],
#  ['cake', 'oil', 'tea'],
#  ['oil', 'strawberries', 'avocado', 'asparagus', 'mayonnaise'],
#  ['shallot',
#   'oil',
#   'gadget for tiktok streaming',
#   'pet food',
#   'portal 2',
#   'half-life: alyx'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'mashed potato',
#   'cooking oil',
#   'beer',
#   'oil',
#   'bacon',
#   'mayonnaise',
#   'gums',
#   'final fantasy XX',
#   'light mayo',
#   'tomato sauce',
#   'chocolate bread',
#   'cauliflower',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'oatmeal',
#   'frozen vegetables',
#   'oil',
#   'deodorant',
#   'gums',
#   'mayonnaise',
#   'yogurt cake',
#   'half-life: alyx',
#   'light mayo',
#   'tomato juice',
#   'cooking oil'],
#  ['cake', 'mashed potato', 'oil', 'gums', 'melons', 'cookies', 'salad', 'tea'],
#  ['spaghetti',
#   'french fries',
#   'oil',
#   'milk',
#   'gums',
#   'melons',
#   'corn',
#   'salmon',
#   'cookies',
#   'megaman zero',
#   'cooking oil',
#   'green grapes',
#   'tea'],
#  ['cake',
#   'oil',
#   'vegetables mix',
#   'fresh bread',
#   'energy drink',
#   'muffins',
#   'extra dark chocolate',
#   'spinach',
#   'green grapes'],
#  ['cake',
#   'french fries',
#   'oil',
#   'deodorant',
#   'red wine',
#   'milk',
#   'gums',
#   'cream',
#   'pancakes',
#   'muffins',
#   'pepper',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['meatballs',
#   'napkins',
#   'cotton buds',
#   'spaghetti',
#   'oil',
#   'gums',
#   'milk',
#   'final fantasy XX',
#   'tea'],
#  ['bramble', 'cake', 'rice', 'fresh bread', 'cologne', 'chocolate bread'],
#  ['cake',
#   'whole wheat pasta',
#   'oil',
#   'french wine',
#   'bacon',
#   'gums',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'whole wheat rice',
#   'rice',
#   'french fries',
#   'oil',
#   'final fantasy XXII',
#   'fresh bread',
#   'whole weat flour',
#   'parmesan cheese',
#   'spinach'],
#  ['soup', 'oil', 'pet food', 'bluetooth headphones'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'whole wheat pasta',
#   'oil',
#   'asparagus',
#   'fresh bread',
#   'pet food',
#   'blueberries',
#   'corn',
#   'ground beef',
#   'toilet paper',
#   'cooking oil',
#   'tea'],
#  ['pickles',
#   'grated cheese',
#   'oil',
#   'tomatoes',
#   'babies food',
#   'metroid prime',
#   'sandwich',
#   'french wine'],
#  ['candy bars',
#   'cake',
#   'turkey',
#   'oil',
#   'fromage blanc',
#   'fresh bread',
#   'gums',
#   'muffins',
#   'fresh tuna'],
#  ['candy bars',
#   'laptop',
#   'oil',
#   'cream',
#   'whole weat flour',
#   'pet food',
#   'megaman zero',
#   'cooking oil'],
#  ['fresh bread', 'oil', 'napkins', 'yogurt cake'],
#  ['cake', 'shower gel', 'babies food', 'tomato sauce', 'zucchini', 'tea'],
#  ['cider',
#   'oatmeal',
#   'cottage cheese',
#   'oil',
#   'ketchup',
#   'shower gel',
#   'blueberries',
#   'cookies',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['oil', 'babies food', 'cooking oil', 'grated cheese'],
#  ['candy bars',
#   'oil',
#   'fromage blanc',
#   'ketchup',
#   'catfish',
#   'mayonnaise',
#   'toothpaste',
#   'shrimp',
#   'blueberries',
#   'cooking oil'],
#  ['dessert wine', 'gums'],
#  ['shampoo',
#   'cake',
#   'eggplant',
#   'french fries',
#   'oil',
#   'champagne',
#   'mayonnaise',
#   'green beans'],
#  ['barbecue sauce',
#   'frozen smoothie',
#   'oil',
#   'shower gel',
#   'tomatoes',
#   'parmesan cheese',
#   'cookies',
#   'megaman zero 4',
#   'cat food',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'cereals',
#   'oil',
#   'ketchup',
#   'gums',
#   'babies food',
#   'pet food',
#   'half-life: alyx',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'cologne', 'gums', 'cookies', 'cooking oil'],
#  ['cake',
#   'hot dogs',
#   'cotton buds',
#   'whole wheat rice',
#   'oil',
#   'fromage blanc',
#   'ketchup',
#   'asparagus',
#   'sparkling water',
#   'pasta',
#   'tea'],
#  ['candy bars',
#   'antioxydant juice',
#   'gums',
#   'yogurt cake',
#   'extra dark chocolate',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'oil',
#   'gums',
#   'shrimp',
#   'muffins',
#   'babies food',
#   'pet food',
#   'minecraft',
#   'extra dark chocolate',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['samsung galaxy 10',
#   'shower gel',
#   'pancakes',
#   'cream',
#   'salmon',
#   'cauliflower',
#   'tea'],
#  ['soup', 'oil', 'fresh bread', 'cream', 'mint'],
#  ['candy bars',
#   'oil',
#   'asparagus',
#   'final fantasy XXII',
#   'gums',
#   'extra dark chocolate',
#   'pepper',
#   'megaman zero 4',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'napkins',
#   'beer',
#   'pokemon shield',
#   'oil',
#   'gluten free bar',
#   'parmesan cheese',
#   'final fantasy XX',
#   'butter',
#   'tea'],
#  ['soda',
#   'cake',
#   'whole wheat rice',
#   'spaghetti',
#   'ring light',
#   'oil',
#   'gadget for tiktok streaming',
#   'half-life: alyx',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['pokemon shield',
#   'cereals',
#   'fresh bread',
#   'gums',
#   'milk',
#   'babies food',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'napkins',
#   'antioxydant juice',
#   'cologne',
#   'samsung galaxy 10',
#   'ketchup',
#   'oil',
#   'airpods',
#   'burgers',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'cake', 'oil', 'cooking oil'],
#  ['cake',
#   'napkins',
#   'spaghetti',
#   'antioxydant juice',
#   'phone charger',
#   'pokemon shield',
#   'milk',
#   'trout',
#   'muffins',
#   'cooking oil'],
#  ['hot dogs', 'oil', 'gums', 'cream', 'ratchet & clank 2'],
#  ['soup',
#   'cake',
#   'megaman zero 3',
#   'oil',
#   'vegetables mix',
#   'fresh bread',
#   'gums',
#   'muffins',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['tooth brush',
#   'whole wheat rice',
#   'spaghetti',
#   'antioxydant juice',
#   'frozen vegetables',
#   'oil',
#   'ketchup',
#   'pokemon scarlet',
#   'tomatoes',
#   'green tea',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'hot dogs',
#   'eggplant',
#   'frozen vegetables',
#   'oil',
#   'champagne',
#   'gums',
#   'muffins',
#   'cookies',
#   'olive oil',
#   'herb & pepper'],
#  ['pickles',
#   'french fries',
#   'strong cheese',
#   'oil',
#   'fresh bread',
#   'cream',
#   'mayonnaise',
#   'muffins',
#   'cookies',
#   'olive oil',
#   'cooking oil'],
#  ['turkey', 'cake', 'oil', 'french wine'],
#  ['candy bars',
#   'dessert wine',
#   'iPad',
#   'rice',
#   'oil',
#   'pet food',
#   'cooking oil'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'french fries',
#   'cereals',
#   'oil',
#   'fresh bread',
#   'pasta',
#   'muffins',
#   'babies food',
#   'cookies',
#   'tomato sauce'],
#  ['soup',
#   'grated cheese',
#   'oil',
#   'catfish',
#   'shower gel',
#   'sandwich',
#   'cooking oil',
#   'metroid fusion'],
#  ['black beer',
#   'oil',
#   'ketchup',
#   'deodorant',
#   'honey',
#   'parmesan cheese',
#   'pasta',
#   'cookies',
#   'olive oil',
#   'cooking oil'],
#  ['black beer',
#   'soup',
#   'cake',
#   'phone charger',
#   'frozen vegetables',
#   'oil',
#   'gums',
#   'eggs',
#   'olive oil',
#   'cooking oil'],
#  ['chocolate',
#   'soup',
#   'napkins',
#   'rice',
#   'cottage cheese',
#   'grated cheese',
#   'oil',
#   'muffins',
#   'sandwich',
#   'burgers',
#   'ratchet & clank 2'],
#  ['shampoo', 'mayonnaise', 'ground beef'],
#  ['candy bars',
#   'energy bar',
#   'french fries',
#   'ketchup',
#   'deodorant',
#   'pokemon sword',
#   'muffins',
#   'pet food',
#   'barbecue sauce',
#   'cooking oil'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'cotton buds',
#   'oil',
#   'cream',
#   'muffins',
#   'cooking oil',
#   'metroid fusion',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'iPad',
#   'cereals',
#   'oil',
#   'canned_tuna',
#   'cologne',
#   'cooking oil'],
#  ['candy bars',
#   'yams',
#   'napkins',
#   'oil',
#   'bacon',
#   'ketchup',
#   'milk',
#   'muffins',
#   'pet food',
#   'olive oil',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['chocolate',
#   'cake',
#   'napkins',
#   'light cream',
#   'oil',
#   'brownies',
#   'muffins',
#   'pet food',
#   'minecraft',
#   'ground beef',
#   'chili',
#   'cooking oil'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'oatmeal',
#   'antioxydant juice',
#   'yogurt cake',
#   'half-life 2',
#   'salmon',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'cooking oil',
#   'fromage blanc',
#   'cookies',
#   'zucchini',
#   'tea'],
#  ['tooth brush',
#   'napkins',
#   'spaghetti',
#   'french fries',
#   'pet food',
#   'babies food',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'french fries', 'oil', 'cooking oil', 'tea'],
#  ['green beans', 'soup', 'yogurt cake', 'cooking oil'],
#  ['candy bars',
#   'hot dogs',
#   'deodorant',
#   'burger sauce',
#   'pokemon scarlet',
#   'tea'],
#  ['soup',
#   'cake',
#   'cottage cheese',
#   'french fries',
#   'pokemon shield',
#   'oil',
#   'frozen smoothie',
#   'sparkling water',
#   'fresh bread',
#   'pasta',
#   'escalope',
#   'cooking oil'],
#  ['cake', 'cereals', 'oil', 'strawberries', 'cream', 'gums', 'milk'],
#  ['candy bars',
#   'french fries',
#   'samsung galaxy 10',
#   'oil',
#   'black tea',
#   'pokemon sword',
#   'cookies',
#   'chicken',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'napkins', 'strong cheese', 'oil', 'cooking oil'],
#  ['spaghetti',
#   'grated cheese',
#   'strong cheese',
#   'oil',
#   'pasta',
#   'bluetooth headphones',
#   'zucchini',
#   'tea'],
#  ['candy bars', 'oil', 'cooking oil', 'tea'],
#  ['soup', 'final fantasy XXII'],
#  ['napkins',
#   'meatballs',
#   'mashed potato',
#   'cottage cheese',
#   'oil',
#   'fresh bread',
#   'gums',
#   'chicken',
#   'fresh tuna',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'oatmeal',
#   'chutney',
#   'final fantasy XIX',
#   'oil',
#   'toothpaste',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'mint green tea',
#   'oil',
#   'fromage blanc',
#   'gums',
#   'carrots',
#   'babies food',
#   'toilet paper'],
#  ['candy bars',
#   'zucchini',
#   'oatmeal',
#   'pokemon violet',
#   'oil',
#   'gums',
#   'cream',
#   'pet food',
#   'sandwich',
#   'olive oil',
#   'cooking oil'],
#  ['soup',
#   'napkins',
#   'ring light',
#   'oil',
#   'cream',
#   'chicken',
#   'megaman zero 4'],
#  ['candy bars',
#   'iphone 10',
#   'soup',
#   'oil',
#   'burger sauce',
#   'vegetables mix',
#   'pokemon scarlet',
#   'cream',
#   'pet food',
#   'megaman zero 2',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soda',
#   'cake',
#   'whole wheat rice',
#   'phone charger',
#   'energy bar',
#   'oil',
#   'deodorant',
#   'gums',
#   'muffins',
#   'metroid prime',
#   'chicken'],
#  ['oil', 'airpods', 'toothpaste', 'hand protein bar', 'muffins', 'tea'],
#  ['cooking oil', 'cauliflower', 'grated cheese'],
#  ['candy bars',
#   'cake',
#   'cottage cheese',
#   'grated cheese',
#   'oil',
#   'low fat yogurt',
#   'fresh bread',
#   'gums',
#   'mayonnaise',
#   'ham',
#   'tea'],
#  ['mineral water', 'cake', 'deodorant', 'toothpaste'],
#  ['cake',
#   'napkins',
#   'oil',
#   'whole weat flour',
#   'barbecue sauce',
#   'cooking oil'],
#  ['napkins', 'oil', 'sandwich', 'metroid fusion', 'cauliflower', 'tea'],
#  ['cake', 'napkins', 'cottage cheese', 'oil', 'yogurt cake'],
#  ['candy bars',
#   'french fries',
#   'oil',
#   'ketchup',
#   'pet food',
#   'ham',
#   'corn',
#   'eggs',
#   'burgers',
#   'body spray',
#   'herb & pepper',
#   'cooking oil'],
#  ['bramble',
#   'ketchup',
#   'cream',
#   'muffins',
#   'ratchet & clank 3',
#   'cookies',
#   'herb & pepper',
#   'tea'],
#  ['candy bars',
#   'eggplant',
#   'french fries',
#   'oil',
#   'ketchup',
#   'black tea',
#   'gums',
#   'cookies'],
#  ['oil', 'cooking oil', 'green grapes', 'tea'],
#  ['cake',
#   'shallot',
#   'oil',
#   'ketchup',
#   'gadget for tiktok streaming',
#   'yogurt cake',
#   'blueberries',
#   'spinach',
#   'olive oil',
#   'cooking oil'],
#  ['rice',
#   'french fries',
#   'oil',
#   'asparagus',
#   'muffins',
#   'yogurt cake',
#   'pet food',
#   'pasta',
#   'cookies',
#   'olive oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'french fries',
#   'avocado',
#   'honey',
#   'champagne',
#   'trout',
#   'chicken',
#   'tomato sauce',
#   'cooking oil'],
#  ['toothpaste', 'oil', 'whole wheat pasta'],
#  ['soup', 'cake', 'oil', 'milk', 'muffins', 'yogurt cake', 'almonds', 'tea'],
#  ['black beer', 'oil', 'whole weat flour', 'muffins', 'tea'],
#  ['fromage blanc', 'yogurt cake', 'cooking oil', 'chocolate bread'],
#  ['portal',
#   'fresh bread',
#   'toothpaste',
#   'hand protein bar',
#   'muffins',
#   'corn',
#   'ratchet & clank 2',
#   'bluetooth headphones',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'energy bar',
#   'oil',
#   'deodorant',
#   'sparkling water',
#   'gums',
#   'muffins',
#   'babies food',
#   'white wine',
#   'vacuum cleaner',
#   'butter',
#   'zucchini',
#   'tea'],
#  ['cider',
#   'soup',
#   'tooth brush',
#   'cake',
#   'oil',
#   'gums',
#   'milk',
#   'muffins',
#   'salt',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'napkins',
#   'spaghetti',
#   'cereals',
#   'oil',
#   'cream',
#   'muffins',
#   'sandwich',
#   'chicken',
#   'bluetooth headphones',
#   'cooking oil'],
#  ['yams',
#   'candy bars',
#   'chocolate',
#   'oil',
#   'shower gel',
#   'fresh bread',
#   'gums',
#   'chicken',
#   'butter',
#   'protein bar'],
#  ['candy bars',
#   'iphone 10',
#   'dessert wine',
#   'rice',
#   'oil',
#   'portal',
#   'deodorant',
#   'mayonnaise',
#   'carrots',
#   'cookies',
#   'tea'],
#  ['candy bars', 'cake', 'rice', 'oil', 'pancakes', 'yogurt cake', 'burgers'],
#  ['french fries', 'escalope', 'chutney', 'cooking oil', 'tea'],
#  ['olive oil', 'oil', 'milk'],
#  ['candy bars', 'soup', 'antioxydant juice', 'ketchup', 'oil'],
#  ['soup',
#   'body spray',
#   'cottage cheese',
#   'oil',
#   'seabass',
#   'sparkling water',
#   'gums',
#   'whole weat flour',
#   'trout',
#   'canned_tuna',
#   'olive oil',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['grated cheese',
#   'oil',
#   'catfish',
#   'fresh bread',
#   'milk',
#   'pet food',
#   'babies food',
#   'tea'],
#  ['bramble',
#   'cake',
#   'hot dogs',
#   'strong cheese',
#   'oil',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['oatmeal', 'oil', 'muffins', 'tea'],
#  ['oil', 'cooking oil', 'tea'],
#  ['cake',
#   'cottage cheese',
#   'oil',
#   'gums',
#   'final fantasy XX',
#   'megaman zero',
#   'cooking oil',
#   'cauliflower',
#   'tea'],
#  ['ratchet & clank', 'dessert wine', 'oil', 'cooking oil'],
#  ['soup',
#   'cake',
#   'napkins',
#   'cologne',
#   'oil',
#   'fromage blanc',
#   'parmesan cheese',
#   'pasta',
#   'carrots',
#   'burgers',
#   'olive oil',
#   'salad',
#   'barbecue sauce',
#   'tea'],
#  ['cider',
#   'dessert wine',
#   'cake',
# ...
#   'tea'],
#  ['candy bars',
#   'cake',
#   'whole wheat rice',
#   'spaghetti',
#   'mashed potato',
#   'olive oil',
#   'seabass',
#   'oil',
#   'gums',
#   'ham',
#   'iMac',
#   'butter',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['cottage cheese',
#   'oil',
#   'fromage blanc',
#   'fresh bread',
#   'cream',
#   'pasta',
#   'pet food',
#   'olive oil'],
#  ['candy bars',
#   'dessert wine',
#   'shallot',
#   'napkins',
#   'oil',
#   'ketchup',
#   'milk',
#   'gums',
#   'hand protein bar'],
#  ['oatmeal',
#   'oil',
#   'strawberries',
#   'deodorant',
#   'melons',
#   'green beans',
#   'olive oil',
#   'cooking oil'],
#  ['shampoo',
#   'french fries',
#   'ring light',
#   'oil',
#   'frozen smoothie',
#   'carrots',
#   'cooking oil'],
#  ['cereals',
#   'oil',
#   'olive oil',
#   'fresh bread',
#   'milk',
#   'megaman zero 2',
#   'cooking oil'],
#  ['soup',
#   'pokemon sword',
#   'pasta',
#   'escalope',
#   'muffins',
#   'green beans',
#   'toilet paper',
#   'butter'],
#  ['soda',
#   'cake',
#   'whole wheat rice',
#   'oatmeal',
#   'french fries',
#   'frozen smoothie',
#   'oil',
#   'phone car charger',
#   'light mayo',
#   'tea'],
#  ['olive oil',
#   'oil',
#   'dog food',
#   'milk',
#   'body spray',
#   'bluetooth headphones',
#   'cooking oil',
#   'tea'],
#  ['oil', 'milk', 'gums', 'tomato juice', 'cooking oil'],
#  ['candy bars',
#   'cake',
#   'rice',
#   'olive oil',
#   'fresh bread',
#   'carrots',
#   'muffins',
#   'toilet paper',
#   'cooking oil'],
#  ['cotton buds',
#   'cereals',
#   'oil',
#   'asparagus',
#   'sparkling water',
#   'yogurt cake',
#   'canned_tuna',
#   'ground beef',
#   'cooking oil',
#   'mushroom cream sauce'],
#  ['candy bars',
#   'cake',
#   'cottage cheese',
#   'oil',
#   'gadget for tiktok streaming',
#   'champagne',
#   'melons',
#   'butter',
#   'cooking oil'],
#  ['yams',
#   'napkins',
#   'mineral water',
#   'oil',
#   'hand protein bar',
#   'megaman zero 2',
#   'tea'],
#  ['soup',
#   'napkins',
#   'spaghetti',
#   'oatmeal',
#   'cottage cheese',
#   'oil',
#   'fresh bread',
#   'pet food',
#   'yogurt cake',
#   'cologne',
#   'salad',
#   'half-life: alyx'],
#  ['oil', 'muffins'],
#  ['candy bars', 'pickles', 'ketchup', 'oil', 'burgers', 'body spray', 'tea'],
#  ['candy bars',
#   'cake',
#   'cotton buds',
#   'mashed potato',
#   'oil',
#   'strawberries',
#   'pokemon scarlet',
#   'pet food',
#   'salad',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'oil',
#   'gums',
#   'parmesan cheese',
#   'milk',
#   'pepper',
#   'cookies',
#   'cooking oil'],
#  ['shampoo',
#   'candy bars',
#   'cake',
#   'cotton buds',
#   'turkey',
#   'oil',
#   'fromage blanc',
#   'gums',
#   'whole weat flour',
#   'muffins',
#   'tea',
#   'eggs',
#   'cologne',
#   'body spray',
#   'salt'],
#  ['pickles',
#   'cake',
#   'rice',
#   'oil',
#   'shower gel',
#   'cream',
#   'yogurt cake',
#   'pet food',
#   'cologne',
#   'tea'],
#  ['iPad',
#   'napkins',
#   'beer',
#   'chocolate bread',
#   'fresh bread',
#   'mayonnaise',
#   'sandwich',
#   'cooking oil',
#   'green grapes',
#   'tea'],
#  ['cake', 'oil', 'pokemon scarlet', 'salad', 'cooking oil', 'tea'],
#  ['black beer', 'french fries', 'oil', 'muffins', 'cooking oil'],
#  ['gums', 'oil', 'spinach'],
#  ['pickles', 'grated cheese', 'oil', 'yogurt cake', 'cooking oil', 'tea'],
#  ['candy bars', 'oil', 'pokemon shield'],
#  ['gums', 'oil', 'yogurt cake', 'cooking oil'],
#  ['soup', 'oil', 'pet food', 'white wine', 'chili', 'cooking oil'],
#  ['hot dogs', 'napkins', 'oil', 'fresh bread', 'fresh tuna', 'tea'],
#  ['shampoo', 'tooth brush', 'frozen smoothie', 'oil', 'gums', 'shrimp', 'tea'],
#  ['soda',
#   'cake',
#   'rice',
#   'phone charger',
#   'french fries',
#   'oil',
#   'avocado',
#   'deodorant',
#   'cologne',
#   'bluetooth headphones'],
#  ['shampoo',
#   'soup',
#   'spaghetti',
#   'ketchup',
#   'oil',
#   'gums',
#   'muffins',
#   'megaman zero 4',
#   'cooking oil'],
#  ['shrimp', 'oil', 'herb & pepper'],
#  ['candy bars',
#   'soup',
#   'whole wheat pasta',
#   'spaghetti',
#   'french fries',
#   'bacon',
#   'oil',
#   'final fantasy XXII',
#   'fresh bread',
#   'gums',
#   'milk',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'oatmeal',
#   'ketchup',
#   'oil',
#   'ham',
#   'sandwich',
#   'eggs',
#   'cooking oil',
#   'tea'],
#  ['whole wheat pasta',
#   'cereals',
#   'oil',
#   'pokemon scarlet',
#   'gums',
#   'toothpaste',
#   'melons',
#   'pet food',
#   'escalope',
#   'zucchini'],
#  ['cake',
#   'whole wheat rice',
#   'rice',
#   'oil',
#   'strawberries',
#   'parmesan cheese',
#   'sandwich',
#   'cookies',
#   'salad',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'napkins',
#   'eggplant',
#   'rice',
#   'frozen smoothie',
#   'tomatoes',
#   'melons',
#   'corn',
#   'cooking oil',
#   'tea'],
#  ['yams', 'cake', 'oatmeal', 'iPad', 'whole weat flour', 'sandwich', 'razor'],
#  ['cake',
#   'iPad',
#   'oil',
#   'dog food',
#   'ham',
#   'sandwich',
#   'half-life: alyx',
#   'chicken',
#   'tomato sauce',
#   'cooking oil',
#   'mushroom cream sauce',
#   'tea'],
#  ['soup',
#   'cake',
#   'iPad',
#   'antioxydant juice',
#   'gums',
#   'toothpaste',
#   'almonds',
#   'salmon',
#   'cookies',
#   'chocolate bread',
#   'tea'],
#  ['cake', 'muffins'],
#  ['gadget for tiktok streaming',
#   'black tea',
#   'whole weat flour',
#   'canned_tuna',
#   'ratchet & clank 2',
#   'cooking oil',
#   'tea'],
#  ['cake', 'napkins', 'spaghetti', 'tea'],
#  ['soup',
#   'cake',
#   'napkins',
#   'soda',
#   'cereals',
#   'oil',
#   'gums',
#   'tomatoes',
#   'muffins',
#   'megaman zero 2',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'meatballs',
#   'french fries',
#   'strong cheese',
#   'oil',
#   'asparagus',
#   'catfish',
#   'shower gel',
#   'gums',
#   'phone car charger',
#   'cookies',
#   'tea'],
#  ['candy bars',
#   'cotton buds',
#   'ketchup',
#   'oil',
#   'asparagus',
#   'gums',
#   'nonfat milk',
#   'babies food',
#   'tea'],
#  ['yams',
#   'oil',
#   'fresh bread',
#   'cream',
#   'whole weat flour',
#   'hand protein bar',
#   'blueberries',
#   'cooking oil'],
#  ['candy bars',
#   'dessert wine',
#   'bramble',
#   'oatmeal',
#   'rice',
#   'razor',
#   'french fries',
#   'oil',
#   'seabass',
#   'avocado',
#   'megaman zero',
#   'babies food',
#   'megaman zero 2',
#   'cat food',
#   'cooking oil',
#   'tea'],
#  ['cookies', 'escalope'],
#  ['candy bars', 'cake', 'spaghetti'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'napkins',
#   'frozen vegetables',
#   'oil',
#   'whole weat flour',
#   'cologne'],
#  ['cider', 'french fries', 'fresh bread', 'mayonnaise', 'gums', 'sandwich'],
#  ['soup', 'oil', 'milk', 'tomato juice', 'cooking oil'],
#  ['fresh bread', 'cake', 'cooking oil'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'hot dogs',
#   'antioxydant juice',
#   'frozen vegetables',
#   'ketchup',
#   'oil',
#   'gums',
#   'toothpaste',
#   'cooking oil',
#   'tea'],
#  ['mineral water',
#   'oil',
#   'frozen vegetables',
#   'strawberries',
#   'sparkling water',
#   'gums',
#   'megaman zero',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'turkey',
#   'oil',
#   'deodorant',
#   'light mayo',
#   'cat food'],
#  ['cake',
#   'napkins',
#   'french fries',
#   'pokemon violet',
#   'oil',
#   'sparkling water',
#   'gums',
#   'muffins',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'oil',
#   'strawberries',
#   'milk',
#   'tomatoes',
#   'muffins',
#   'olive oil',
#   'cooking oil'],
#  ['napkins', 'cotton buds', 'oil', 'gums', 'cream', 'eggs', 'cooking oil'],
#  ['cake',
#   'rice',
#   'oil',
#   'whole weat flour',
#   'muffins',
#   'brownies',
#   'blueberries',
#   'eggs'],
#  ['shampoo', 'cider', 'shallot', 'airpods', 'oil', 'olive oil', 'cooking oil'],
#  ['candy bars', 'napkins', 'oil', 'ketchup', 'cookies', 'cooking oil', 'tea'],
#  ['cake',
#   'mineral water',
#   'ketchup',
#   'gums',
#   'pet food',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['oatmeal',
#   'pokemon violet',
#   'final fantasy XXII',
#   'pokemon scarlet',
#   'whole weat flour',
#   'pet food',
#   'light mayo',
#   'tea'],
#  ['cake',
#   'oatmeal',
#   'cereals',
#   'oil',
#   'asparagus',
#   'whole weat flour',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'pokemon violet',
#   'bacon',
#   'oil',
#   'black tea',
#   'gums',
#   'pasta',
#   'pet food',
#   'canned_tuna',
#   'cookies',
#   'olive oil'],
#  ['cider',
#   'ring light',
#   'asparagus',
#   'gums',
#   'parmesan cheese',
#   'zucchini',
#   'cauliflower'],
#  ['candy bars',
#   'cottage cheese',
#   'oil',
#   'catfish',
#   'muffins',
#   'babies food',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'whole wheat rice',
#   'napkins',
#   'chutney',
#   'frozen vegetables',
#   'oil',
#   'fromage blanc',
#   'fresh bread',
#   'ground beef',
#   'bluetooth headphones',
#   'cooking oil',
#   'salt'],
#  ['cake',
#   'napkins',
#   'cottage cheese',
#   'strong cheese',
#   'oil',
#   'flax seed',
#   'muffins',
#   'minecraft',
#   'yogurt cake',
#   'cooking oil',
#   'tea'],
#  ['shampoo',
#   'cake',
#   'oil',
#   'cream',
#   'parmesan cheese',
#   'muffins',
#   'gums',
#   'escalope',
#   'cooking oil',
#   'tea'],
#  ['shampoo',
#   'candy bars',
#   'soup',
#   'napkins',
#   'oatmeal',
#   'ketchup',
#   'gums',
#   'melons',
#   'ratchet & clank 3',
#   'cookies',
#   'chicken',
#   'butter',
#   'cooking oil',
#   'tea'],
#  ['cake', 'napkins', 'oil', 'gluten free bar', 'pokemon sword', 'tea'],
#  ['candy bars',
#   'cake',
#   'strong cheese',
#   'oil',
#   'airpods',
#   'dog food',
#   'asparagus',
#   'megaman zero',
#   'yogurt cake',
#   'portal 2',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['cotton buds',
#   'oil',
#   'toothpaste',
#   'gums',
#   'cream',
#   'milk',
#   'ham',
#   'salmon',
#   'iMac',
#   'olive oil',
#   'toilet paper',
#   'cooking oil'],
#  ['soup', 'cake', 'oil', 'gums', 'cookies', 'olive oil', 'cooking oil', 'tea'],
#  ['soda',
#   'soup',
#   'rice',
#   'strong cheese',
#   'oil',
#   'fromage blanc',
#   'asparagus',
#   'fresh bread',
#   'mayonnaise',
#   'pet food',
#   'green beans',
#   'megaman zero 4',
#   'mint',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'oil',
#   'fromage blanc',
#   'champagne',
#   'muffins',
#   'ham',
#   'cookies',
#   'cooking oil'],
#  ['candy bars',
#   'cake',
#   'napkins',
#   'oil',
#   'catfish',
#   'gums',
#   'pasta',
#   'yogurt cake',
#   'minecraft',
#   'sandwich',
#   'corn',
#   'portal 2',
#   'cooking oil',
#   'tea'],
#  ['candy bars', 'oil'],
#  ['spaghetti',
#   'oil',
#   'cream',
#   'trout',
#   'pasta',
#   'yogurt cake',
#   'escalope',
#   'corn',
#   'muffins',
#   'body spray',
#   'cooking oil'],
#  ['olive oil', 'bacon', 'fromage blanc', 'tea'],
#  ['cake',
#   'cat food',
#   'olive oil',
#   'oil',
#   'gums',
#   'cream',
#   'chicken',
#   'tomato sauce',
#   'cooking oil'],
#  ['napkins',
#   'hot dogs',
#   'oil',
#   'black tea',
#   'fresh bread',
#   'gums',
#   'toilet paper',
#   'green grapes'],
#  ['antioxydant juice',
#   'oil',
#   'honey',
#   'cream',
#   'muffins',
#   'escalope',
#   'cologne'],
#  ['cider',
#   'cake',
#   'oil',
#   'vegetables mix',
#   'milk',
#   'yogurt cake',
#   'final fantasy XX'],
#  ['candy bars',
#   'tooth brush',
#   'cake',
#   'napkins',
#   'yams',
#   'mashed potato',
#   'olive oil',
#   'oil',
#   'seabass',
#   'chocolate bread',
#   'gums',
#   'carrots',
#   'sandwich',
#   'iMac',
#   'body spray',
#   'cooking oil'],
#  ['candy bars',
#   'cake',
#   'oil',
#   'ketchup',
#   'fresh bread',
#   'cream',
#   'carrots',
#   'muffins',
#   'ratchet & clank',
#   'pet food',
#   'cooking oil',
#   'tea'],
#  ['napkins',
#   'energy bar',
#   'oil',
#   'seabass',
#   'cream',
#   'milk',
#   'yogurt cake',
#   'olive oil',
#   'cooking oil',
#   'cauliflower'],
#  ['candy bars', 'oil', 'muffins', 'tea'],
#  ['candy bars',
#   'soup',
#   'bramble',
#   'whole wheat rice',
#   'oatmeal',
#   'oil',
#   'black tea',
#   'dog food',
#   'gums',
#   'muffins',
#   'toilet paper',
#   'cauliflower',
#   'tea'],
#  ['oil', 'rice', 'tea'],
#  ['olive oil', 'salt'],
#  ['candy bars',
#   'soda',
#   'napkins',
#   'rice',
#   'laptop',
#   'oil',
#   'whole weat flour',
#   'muffins',
#   'tomatoes',
#   'extra dark chocolate',
#   'toilet paper',
#   'green grapes',
#   'tea'],
#  ['black beer',
#   'soda',
#   'cake',
#   'turkey',
#   'oil',
#   'asparagus',
#   'escalope',
#   'ratchet & clank 3',
#   'bluetooth headphones'],
#  ['bramble',
#   'hot dogs',
#   'oil',
#   'flax seed',
#   'muffins',
#   'pasta',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['cake', 'cottage cheese', 'oil', 'cologne', 'cooking oil', 'tea'],
#  ['cake',
#   'rice',
#   'french fries',
#   'oil',
#   'parmesan cheese',
#   'body spray',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'soup',
#   'napkins',
#   'whole wheat rice',
#   'cereals',
#   'oil',
#   'fresh bread',
#   'gums',
#   'megaman zero 2',
#   'cooking oil',
#   'tea'],
#  ['strong cheese',
#   'oil',
#   'asparagus',
#   'half-life 2',
#   'cookies',
#   'cooking oil',
#   'tea'],
#  ['oil', 'cookies', 'water spray', 'tomato sauce', 'tea'],
#  ['butter',
#   'yogurt cake',
#   'ground beef',
#   'phone car charger',
#   'mint',
#   'red wine',
#   'tea'],
#  ['tooth brush',
#   'hot dogs',
#   'napkins',
#   'rice',
#   'frozen vegetables',
#   'toilet paper',
#   'herb & pepper',
#   'tea'],
#  ['shampoo',
#   'candy bars',
#   'oil',
#   'cream',
#   'pet food',
#   'babies food',
#   'red wine',
#   'french wine'],
#  ['candy bars',
#   'cake',
#   'rice',
#   'bacon',
#   'oil',
#   'fresh bread',
#   'whole weat flour',
#   'pasta',
#   'brownies',
#   'half-life: alyx',
#   'eggs',
#   'body spray',
#   'cooking oil',
#   'tea'],
#  ['soup',
#   'cake',
#   'napkins',
#   'beer',
#   'french fries',
#   'oil',
#   'deodorant',
#   'spinach',
#   'cream',
#   'babies food',
#   'yogurt cake',
#   'final fantasy XX',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'oil',
#   'whole weat flour',
#   'babies food',
#   'minecraft',
#   'ground beef',
#   'phone car charger',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['shampoo',
#   'soup',
#   'cake',
#   'pickles',
#   'hot dogs',
#   'grated cheese',
#   'gums',
#   'tomatoes',
#   'muffins',
#   'red wine',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'iPad',
#   'pokemon shield',
#   'ground beef',
#   'olive oil',
#   'cooking oil'],
#  ['napkins',
#   'french fries',
#   'frozen smoothie',
#   'oil',
#   'ketchup',
#   'turkey',
#   'toothpaste',
#   'carrots',
#   'muffins',
#   'salmon',
#   'megaman zero'],
#  ['soup',
#   'cake',
#   'oil',
#   'airpods',
#   'gums',
#   'muffins',
#   'metroid prime',
#   'eggs',
#   'cooking oil',
#   'tea'],
#  ['cake', 'hot dogs', 'oil', 'ratchet & clank 2', 'cooking oil', 'tea'],
#  ['napkins', 'oil', 'avocado', 'low fat yogurt', 'gums', 'cooking oil', 'tea'],
#  ['cake',
#   'iPad',
#   'cooking oil',
#   'oil',
#   'seabass',
#   'gums',
#   'toothpaste',
#   'yogurt cake',
#   'ratchet & clank 3',
#   'zucchini'],
#  ['yams',
#   'soup',
#   'cake',
#   'meatballs',
#   'cereals',
#   'oil',
#   'fresh bread',
#   'milk',
#   'babies food',
#   'pepper',
#   'phone car charger',
#   'megaman zero 4',
#   'cooking oil',
#   'tea'],
#  ['soup', 'oil'],
#  ['pickles',
#   'soup',
#   'tooth brush',
#   'cake',
#   'strong cheese',
#   'oil',
#   'ketchup',
#   'catfish',
#   'toothpaste',
#   'whole weat flour',
#   'muffins',
#   'babies food',
#   'cooking oil'],
#  ['candy bars',
#   'cake',
#   'cereals',
#   'oil',
#   'fresh bread',
#   'muffins',
#   'burgers',
#   'body spray'],
#  ['cake',
#   'french fries',
#   'oil',
#   'dog food',
#   'gums',
#   'vacuum cleaner',
#   'red wine'],
#  ['mineral water', 'muffins'],
#  ['candy bars',
#   'cake',
#   'light cream',
#   'grated cheese',
#   'laptop',
#   'oil',
#   'asparagus',
#   'shrimp',
#   'milk',
#   'almonds',
#   'corn',
#   'green grapes'],
#  ['candy bars',
#   'soup',
#   'pickles',
#   'phone charger',
#   'razor',
#   'frozen vegetables',
#   'ketchup',
#   'fresh bread',
#   'whole weat flour',
#   'corn',
#   'ratchet & clank 3',
#   'cookies',
#   'toilet paper',
#   'tomato sauce',
#   'cooking oil',
#   'tea'],
#  ['candy bars',
#   'cake',
#   'turkey',
#   'cereals',
#   'oil',
#   'megaman zero 2',
#   'cooking oil',
#   'tea'],
#  ['gums', 'pasta'],
#  ['candy bars',
#   'soup',
#   'cake',
#   'napkins',
#   'cotton buds',
#   'oatmeal',
#   'oil',
#   'gums',
#   'nonfat milk',
#   'mint',
#   'tea'],
#  ['cake',
#   'cotton buds',
#   'oil',
#   'cream',
#   'whole weat flour',
#   'babies food',
#   'cooking oil'],
#  ['soup',
#   'napkins',
#   'spaghetti',
#   'rice',
#   'cotton buds',
#   'french fries',
#   'oil',
#   'sparkling water',
#   'whole weat flour',
#   'muffins',
#   'ground beef',
#   'tomato sauce',
#   'fresh tuna',
#   'cauliflower',
#   'tea'],
#  ['bramble',
#   'candy bars',
#   'strong cheese',
#   'cereals',
#   'oil',
#   'pokemon shield',
#   'gadget for tiktok streaming',
#   'gums',
#   'pasta',
#   'minecraft',
#   'olive oil',
#   'toilet paper',
#   'tea'],
#  ['meatballs',
#   'turkey',
#   'megaman zero',
#   'corn',
#   'yogurt cake',
#   'ham',
#   'olive oil',
#   'cooking oil',
#   'tea'],
#  ['cake',
#   'rice',
#   'turkey',
#   'oil',
#   'final fantasy XXII',
#   'fresh bread',
#   'olive oil',
#   'mint',
#   'cooking oil'],
#  ['candy bars',
#   'napkins',
#   'cotton buds',
#   'strong cheese',
#   'ketchup',
#   'oil',
#   'gums',
#   'pancakes',
#   'cooking oil',
#   'tea'],
#  ...]

# %%
eclat_algorithm(items_list2, min_combination = 2, max_combination = 2, min_support = 0.02)
# Out:
# Combination 2 by 2
# 6786it [01:14, 91.36it/s]
#                             support
# oil & cooking oil          0.428647
# tea & oil                  0.426828
# cake & oil                 0.329480
# tea & cooking oil          0.304542
# candy bars & oil           0.261237
# ...                             ...
# napkins & rice             0.020185
# shallot & oil              0.020185
# tea & deodorant            0.020185
# babies food & fresh bread  0.020127
# olive oil & ketchup        0.020127
#
# [306 rows x 1 columns]
