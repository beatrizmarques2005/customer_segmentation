# %% [markdown]
# # **PREPROCESSING NOTEBOOK**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import seaborn as sns
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Get the absolute path of the source_code folder
source_code_path = os.path.abspath('../source_code')

# Add the source_code folder to sys.path
if source_code_path not in sys.path:
    sys.path.append(source_code_path)

# %%
from utils import *
from preprocessing import *

# %% [markdown]
# ## Load Data

# %%
customer_info = load_dataset('../customer_info.csv')

# %%
customer_info
# Out:
#        customer_id      customer_name customer_gender   customer_birthdate  \
# 0            29930        April Clark          female  01/15/1972 02:27 PM
# 1             6813  Bsc. Paul Ketchum            male  07/31/1944 10:53 AM
# 2            39451       Mary Downing          female  11/13/1989 02:11 PM
# 3            21557       Manuel Kueny            male  08/09/1976 06:23 AM
# 4            16415  Phd. Curtis Tharp            male  07/11/1966 08:12 AM
# ...            ...                ...             ...                  ...
# 34055        37071          Mary Diaz          female  01/20/1999 06:47 PM
# 34056        27422         John Gross            male  08/01/1984 07:50 PM
# 34057        39540    Kathleen Harper          female  09/16/2000 07:22 AM
# 34058        18367  Msc. Jenny Landry          female  04/09/1961 10:52 AM
# 34059        22050        Roy Wilkins            male  03/25/1993 09:59 PM
#
# ...

# %%
customer_basket = load_dataset('../customer_basket.csv')

# %%
customer_basket
# Out:
#        invoice_id                                      list_of_goods  \
# 0         5062209  ['megaman zero 3', 'energy bar', 'pokemon viol...
# 1         4272512  ['black beer', 'bramble', 'laptop', 'pokemon v...
# 2         7121052  ['soup', 'shallot', 'cake', 'fresh bread', 'cr...
# 3         5847748  ['soup', 'cooking oil', 'cereals', 'oil', 'dog...
# 4         6336114  ['eggplant', 'mint green tea', 'oil', 'bacon',...
# ...           ...                                                ...
# 99995     5389466  ['frozen smoothie', 'avocado', 'dog food', 'ch...
# 99996    10387390  ['cake', 'antioxydant juice', 'honey', 'toothp...
# 99997     7103407  ['candy bars', 'spaghetti', 'oil', 'final fant...
# 99998     4093515  ['shallot', 'cereals', 'oil', 'deodorant', 'me...
# 99999     6611217  ['soup', 'napkins', 'pokemon violet', 'ratchet...
#
#        customer_id
# 0             4925
# 1            19046
# 2            10318
# 3            27283
# 4            16072
# ...

# %%
customer_basket, goods_summary = correct_customer_backet_format(customer_basket)

# %%
customer_basket
# Out:
#        invoice_id                                      list_of_goods  \
# 0         5062209  [megaman zero 3, energy bar, pokemon violet, a...
# 1         4272512  [black beer, bramble, laptop, pokemon violet, ...
# 2         7121052  [soup, shallot, cake, fresh bread, cream, carr...
# 3         5847748  [soup, cooking oil, cereals, oil, dog food, de...
# 4         6336114  [eggplant, mint green tea, oil, bacon, toilet ...
# ...           ...                                                ...
# 99995     5389466  [frozen smoothie, avocado, dog food, chili, ch...
# 99996    10387390  [cake, antioxydant juice, honey, toothpaste, t...
# 99997     7103407  [candy bars, spaghetti, oil, final fantasy XXI...
# 99998     4093515  [shallot, cereals, oil, deodorant, metroid pri...
# 99999     6611217  [soup, napkins, pokemon violet, ratchet & clan...
#
#        customer_id  number_of_items
# 0             4925              198
# 1            19046              179
# ...

# %%
goods_summary
# Out:
#          list_of_goods  invoice_count  customer_count
# 0              airpods           7255            5327
# 1              almonds           3595            3055
# 2    antioxydant juice           3581            3012
# 3            asparagus          15906            8220
# 4              avocado           7150            4979
# ..                 ...            ...             ...
# 159  whole wheat pasta           2554            2389
# 160   whole wheat rice           4377            3798
# 161               yams           2619            2407
# 162        yogurt cake           5793            4792
# 163           zucchini           4739            3834
#
# [164 rows x 3 columns]

# %% [markdown]
# ## _Customer Info_

# %%
initial_exploration(customer_info)
# Out:
# First few rows of the dataset:
#    customer_id      customer_name customer_gender   customer_birthdate  \
# 0        29930        April Clark          female  01/15/1972 02:27 PM
# 1         6813  Bsc. Paul Ketchum            male  07/31/1944 10:53 AM
# 2        39451       Mary Downing          female  11/13/1989 02:11 PM
# 3        21557       Manuel Kueny            male  08/09/1976 06:23 AM
# 4        16415  Phd. Curtis Tharp            male  07/11/1966 08:12 AM
#
#    kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0        2.0         2.0                1.0                      4.0
# 1        0.0         1.0                0.0                      4.0
# 2        2.0         3.0                0.0                      7.0
# 3        0.0         0.0                1.0                      1.0
# 4        1.0         1.0                1.0                      5.0
#
#    lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# ...

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration
check_duplicates(customer_info)
# Out:
# Number of duplicate rows: 0
# 0

# %%
# Treatment
customer_info = treat_duplicates(customer_info)
# Out:
# Duplicates have been removed.

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration
customer_info.info()

# %%
customer_info.describe().T

# %%
# Treatment
customer_info.isnull().sum()

# %%
#cannot impute for customer_birthdate and loylty_card_number

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ## _Customer Basket_

# %%
initial_exploration(customer_basket)

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration
check_duplicates(customer_basket)

# %%
# Treatment

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration
check_duplicates(customer_basket)

# %%
# Treatment
customer_basket = treat_duplicates(customer_basket)

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment
