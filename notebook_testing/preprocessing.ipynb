# %% [markdown]
# # **PREPROCESSING NOTEBOOK**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv('../customer_info.csv',index_col=0)
data.head()
# Out:
#    customer_id      customer_name customer_gender   customer_birthdate  \
# 0        29930        April Clark          female  01/15/1972 02:27 PM
# 1         6813  Bsc. Paul Ketchum            male  07/31/1944 10:53 AM
# 2        39451       Mary Downing          female  11/13/1989 02:11 PM
# 3        21557       Manuel Kueny            male  08/09/1976 06:23 AM
# 4        16415  Phd. Curtis Tharp            male  07/11/1966 08:12 AM
#
#    kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0        2.0         2.0                1.0                      4.0
# 1        0.0         1.0                0.0                      4.0
# 2        2.0         3.0                0.0                      7.0
# 3        0.0         0.0                1.0                      1.0
# 4        1.0         1.0                1.0                      5.0
#
#    lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# ...

# %%
customer_info = pd.read_csv('D:\OneDrive - NOVAIMS\Year 2\S4\Machine Learning ll\Project\ML2_Group9\customer_info.csv', index_col=0)
customer_info.head()
# Out:
#    customer_id      customer_name customer_gender   customer_birthdate  \
# 0        29930        April Clark          female  01/15/1972 02:27 PM
# 1         6813  Bsc. Paul Ketchum            male  07/31/1944 10:53 AM
# 2        39451       Mary Downing          female  11/13/1989 02:11 PM
# 3        21557       Manuel Kueny            male  08/09/1976 06:23 AM
# 4        16415  Phd. Curtis Tharp            male  07/11/1966 08:12 AM
#
#    kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0        2.0         2.0                1.0                      4.0
# 1        0.0         1.0                0.0                      4.0
# 2        2.0         3.0                0.0                      7.0
# 3        0.0         0.0                1.0                      1.0
# 4        1.0         1.0                1.0                      5.0
#
#    lifetime_spend_groceries  lifetime_spend_electronics  ...  \
# ...

# %%
data1 = pd.read_csv('../customer_basket.csv')
data1
# Out:
#        invoice_id                                      list_of_goods  \
# 0         5062209  ['megaman zero 3', 'energy bar', 'pokemon viol...
# 1         4272512  ['black beer', 'bramble', 'laptop', 'pokemon v...
# 2         7121052  ['soup', 'shallot', 'cake', 'fresh bread', 'cr...
# 3         5847748  ['soup', 'cooking oil', 'cereals', 'oil', 'dog...
# 4         6336114  ['eggplant', 'mint green tea', 'oil', 'bacon',...
# ...           ...                                                ...
# 99995     5389466  ['frozen smoothie', 'avocado', 'dog food', 'ch...
# 99996    10387390  ['cake', 'antioxydant juice', 'honey', 'toothp...
# 99997     7103407  ['candy bars', 'spaghetti', 'oil', 'final fant...
# 99998     4093515  ['shallot', 'cereals', 'oil', 'deodorant', 'me...
# 99999     6611217  ['soup', 'napkins', 'pokemon violet', 'ratchet...
#
#        customer_id
# 0             4925
# 1            19046
# 2            10318
# 3            27283
# 4            16072
# ...

# %%
customer_basket = pd.read_csv('D:\OneDrive - NOVAIMS\Year 2\S4\Machine Learning ll\Project\ML2_Group9\customer_basket.csv', sep=',')
customer_basket.head()
# Out:
#    invoice_id                                      list_of_goods  customer_id
# 0     5062209  ['megaman zero 3', 'energy bar', 'pokemon viol...         4925
# 1     4272512  ['black beer', 'bramble', 'laptop', 'pokemon v...        19046
# 2     7121052  ['soup', 'shallot', 'cake', 'fresh bread', 'cr...        10318
# 3     5847748  ['soup', 'cooking oil', 'cereals', 'oil', 'dog...        27283
# 4     6336114  ['eggplant', 'mint green tea', 'oil', 'bacon',...        16072

# %% [markdown]
# ## _Customer Info_

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ## _Customer Basket_

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment
