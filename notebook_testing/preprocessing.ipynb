# %% [markdown]
# # **PREPROCESSING NOTEBOOK**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
customer_info = pd.read_csv('../customer_info.csv', index_col=0)
customer_info.head()

# %%
customer_basket = pd.read_csv('../customer_basket.csv')
customer_basket.head()

# %% [markdown]
# ## _Customer Info_

# %% [markdown]
# ### 0. General

# %%
print(f'customer_info shape: {customer_info.shape}')

# %%
print(f'customer_info main metrics: \n')
customer_info.describe().T

# %%
customer_info.describe(include='object').T

# %%
customer_info.info()

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration
customer_info_duplicated = customer_info[customer_info.duplicated()]
customer_info_duplicated.head()

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ## _Customer Basket_

# %% [markdown]
# ### 0. General

# %%
# Explode the list_of_goods column to have one item per row
customer_basket['list_of_goods'] = customer_basket['list_of_goods'].apply(eval)  # Convert string representation of list to actual list
exploded_basket = customer_basket.explode('list_of_goods')

# Group by list_of_goods and count unique invoice_ids and customer_ids
goods_summary = exploded_basket.groupby('list_of_goods').agg(
    invoice_count=('invoice_id', 'nunique'),
    customer_count=('customer_id', 'nunique')
).reset_index()

display(goods_summary)

# %%
print(f'goods_summary shape: {goods_summary.shape}')

# %%
print(f'goods_summary main metrics: \n')
goods_summary.describe().T

# %%
goods_summary.describe(include = 'O').T

# %%
customer_basket.info()

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration
goods_summary_duplicated = goods_summary[goods_summary.duplicated()]
goods_summary_duplicated.head()
#test

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment
