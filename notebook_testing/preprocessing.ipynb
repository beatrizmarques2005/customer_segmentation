# %% [markdown]
# # **PREPROCESSING NOTEBOOK**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import seaborn as sns
#hello

# %% [markdown]
# ## Load Data

# %%
customer_info = pd.read_csv('../customer_info.csv',index_col=0)
customer_info.head()

# %%
customer_basket = pd.read_csv('../customer_basket.csv')
customer_basket.head()

# %% [markdown]
# ## _Customer Info_

# %%
print(f'customer_info shape: {customer_info.shape}')

# %%
print(f'customer_info main metrics: \n')
customer_info.describe().T

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration
customer_info.info()

# %%
customer_info.describe().T

# %%
# Treatment
customer_info.isnull().sum()

# %%
#cannot impute for customer_birthdate and loylty_card_number

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ## _Customer Basket_

# %% [markdown]
# ### 0. General

# %%
customer_info[customer_info.isna().sum(axis=1) == 4]

# %% [markdown]
# ### 4. Encoding

# %%
customer_info.select_dtypes(include = object)

# %%
customer_info.describe(include = object)

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# # Exploration
# goods_summary_duplicated = goods_summary[goods_summary.duplicated()]
# goods_summary_duplicated.head()

# %%
# Treatment

# %% [markdown]
# ## _Customer Basket_

# %% [markdown]
# ### 1. Duplicates

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 2. Outliers

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 3. Missing Values

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 4. Encoding

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 5. Inconsistencies

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 6. Scalling

# %%
# Exploration

# %%
# Treatment

# %% [markdown]
# ### 7. Redundancy

# %%
# Exploration

# %%
# Treatment
